# %% [markdown]
# # Full npe with context

# %%
from JHPY import *

# %%
outputs = generate_sine_data(num_simulations=100000, batch_size=2048)
# Out:
# generating 10000 samples for training
# data generated

# %%
config = {
            'data_dim': 1000,
            'param_dim': 3,
            'context_dim': 128,
            'num_flow_layers': 10,
            'hidden_dim': 256,
        }

model = DINGOModel(config=config)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.5, patience=8
)

training_stuff = train_npe_model(model, optimizer, 200, outputs["Train_Loader"], outputs["Val_Loader"], scheduler=scheduler, patience=20, dropout_rate=0.1, save_best_model=True)
# Out:
# Epoch 1, training: 100%|██████████| 32/32 [00:01<00:00, 27.75it/s]
# Epoch 1, validation: 100%|██████████| 4/4 [00:00<00:00, 101.63it/s]
# [Epoch  1]
# Training - Log Prob: -4.6375
# Validation - Log Prob: -3.2544
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 2, training: 100%|██████████| 32/32 [00:01<00:00, 27.87it/s]
# Epoch 2, validation: 100%|██████████| 4/4 [00:00<00:00, 101.52it/s]
# [Epoch  2]
# Training - Log Prob: -2.7393
# Validation - Log Prob: -2.1207
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 3, training: 100%|██████████| 32/32 [00:01<00:00, 26.45it/s]
# Epoch 3, validation: 100%|██████████| 4/4 [00:00<00:00, 92.03it/s]
# [Epoch  3]
# Training - Log Prob: -1.7810
# Validation - Log Prob: -1.4567
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 4, training: 100%|██████████| 32/32 [00:01<00:00, 25.65it/s]
# Epoch 4, validation: 100%|██████████| 4/4 [00:00<00:00, 90.91it/s]
# [Epoch  4]
# Training - Log Prob: -1.2849
# Validation - Log Prob: -1.0180
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 5, training: 100%|██████████| 32/32 [00:01<00:00, 28.09it/s]
# Epoch 5, validation: 100%|██████████| 4/4 [00:00<00:00, 106.65it/s]
# [Epoch  5]
# Training - Log Prob: -0.6664
# Validation - Log Prob: -0.4694
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 6, training: 100%|██████████| 32/32 [00:01<00:00, 27.85it/s]
# Epoch 6, validation: 100%|██████████| 4/4 [00:00<00:00, 95.04it/s]
# [Epoch  6]
# Training - Log Prob: -0.8010
# Validation - Log Prob: -0.3482
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 7, training: 100%|██████████| 32/32 [00:01<00:00, 26.67it/s]
# Epoch 7, validation: 100%|██████████| 4/4 [00:00<00:00, 101.15it/s]
# [Epoch  7]
# Training - Log Prob: 0.2991
# Validation - Log Prob: -0.1017
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 8, training: 100%|██████████| 32/32 [00:01<00:00, 28.16it/s]
# Epoch 8, validation: 100%|██████████| 4/4 [00:00<00:00, 94.74it/s]
# [Epoch  8]
# Training - Log Prob: 0.4492
# Validation - Log Prob: 0.7476
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 9, training: 100%|██████████| 32/32 [00:01<00:00, 28.03it/s]
# Epoch 9, validation: 100%|██████████| 4/4 [00:00<00:00, 89.13it/s]
# [Epoch  9]
# Training - Log Prob: 1.0788
# Validation - Log Prob: 1.2711
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 10, training: 100%|██████████| 32/32 [00:01<00:00, 27.17it/s]
# Epoch 10, validation: 100%|██████████| 4/4 [00:00<00:00, 86.44it/s]
# [Epoch 10]
# Training - Log Prob: 1.3648
# Validation - Log Prob: 1.3263
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 11, training: 100%|██████████| 32/32 [00:01<00:00, 26.35it/s]
# Epoch 11, validation: 100%|██████████| 4/4 [00:00<00:00, 92.78it/s]
# [Epoch 11]
# Training - Log Prob: 1.8045
# Validation - Log Prob: 1.6247
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 12, training: 100%|██████████| 32/32 [00:01<00:00, 26.86it/s]
# Epoch 12, validation: 100%|██████████| 4/4 [00:00<00:00, 93.93it/s]
# [Epoch 12]
# Training - Log Prob: 2.3107
# Validation - Log Prob: 2.3792
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 13, training: 100%|██████████| 32/32 [00:01<00:00, 27.31it/s]
# Epoch 13, validation: 100%|██████████| 4/4 [00:00<00:00, 98.78it/s]
# [Epoch 13]
# Training - Log Prob: 2.5751
# Validation - Log Prob: 2.1889
# Current learning rates: [0.0005]
# Epoch 14, training: 100%|██████████| 32/32 [00:01<00:00, 28.64it/s]
# Epoch 14, validation: 100%|██████████| 4/4 [00:00<00:00, 87.95it/s]
# [Epoch 14]
# Training - Log Prob: 2.6116
# Validation - Log Prob: 2.8837
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 15, training: 100%|██████████| 32/32 [00:01<00:00, 25.91it/s]
# Epoch 15, validation: 100%|██████████| 4/4 [00:00<00:00, 93.50it/s]
# [Epoch 15]
# Training - Log Prob: 2.3713
# Validation - Log Prob: 2.4763
# Current learning rates: [0.0005]
# Epoch 16, training: 100%|██████████| 32/32 [00:01<00:00, 27.63it/s]
# Epoch 16, validation: 100%|██████████| 4/4 [00:00<00:00, 107.51it/s]
# [Epoch 16]
# Training - Log Prob: 2.7445
# Validation - Log Prob: 1.9830
# Current learning rates: [0.0005]
# Epoch 17, training: 100%|██████████| 32/32 [00:01<00:00, 27.88it/s]
# Epoch 17, validation: 100%|██████████| 4/4 [00:00<00:00, 98.29it/s]
# [Epoch 17]
# Training - Log Prob: 2.3065
# Validation - Log Prob: 2.1710
# Current learning rates: [0.0005]
# Epoch 18, training: 100%|██████████| 32/32 [00:01<00:00, 27.63it/s]
# Epoch 18, validation: 100%|██████████| 4/4 [00:00<00:00, 100.45it/s]
# [Epoch 18]
# Training - Log Prob: 2.8216
# Validation - Log Prob: 1.9485
# Current learning rates: [0.0005]
# Epoch 19, training: 100%|██████████| 32/32 [00:01<00:00, 27.90it/s]
# Epoch 19, validation: 100%|██████████| 4/4 [00:00<00:00, 104.10it/s]
# [Epoch 19]
# Training - Log Prob: 2.5977
# Validation - Log Prob: 2.3575
# Current learning rates: [0.0005]
# Epoch 20, training: 100%|██████████| 32/32 [00:01<00:00, 27.97it/s]
# Epoch 20, validation: 100%|██████████| 4/4 [00:00<00:00, 95.83it/s]
# [Epoch 20]
# Training - Log Prob: 2.5739
# Validation - Log Prob: 2.0990
# Current learning rates: [0.0005]
# Epoch 21, training: 100%|██████████| 32/32 [00:01<00:00, 27.00it/s]
# Epoch 21, validation: 100%|██████████| 4/4 [00:00<00:00, 86.22it/s]
# [Epoch 21]
# Training - Log Prob: 2.9866
# Validation - Log Prob: 3.1926
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 22, training: 100%|██████████| 32/32 [00:01<00:00, 27.99it/s]
# Epoch 22, validation: 100%|██████████| 4/4 [00:00<00:00, 97.45it/s]
# [Epoch 22]
# Training - Log Prob: 3.5539
# Validation - Log Prob: 3.0184
# Current learning rates: [0.0005]
# Epoch 23, training: 100%|██████████| 32/32 [00:01<00:00, 26.72it/s]
# Epoch 23, validation: 100%|██████████| 4/4 [00:00<00:00, 95.44it/s]
# [Epoch 23]
# Training - Log Prob: 3.6633
# Validation - Log Prob: 3.2832
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 24, training: 100%|██████████| 32/32 [00:01<00:00, 28.12it/s]
# Epoch 24, validation: 100%|██████████| 4/4 [00:00<00:00, 102.55it/s]
# [Epoch 24]
# Training - Log Prob: 3.5762
# Validation - Log Prob: 3.5589
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 25, training: 100%|██████████| 32/32 [00:01<00:00, 27.95it/s]
# Epoch 25, validation: 100%|██████████| 4/4 [00:00<00:00, 99.62it/s]
# [Epoch 25]
# Training - Log Prob: 4.0270
# Validation - Log Prob: 3.6228
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 26, training: 100%|██████████| 32/32 [00:01<00:00, 28.41it/s]
# Epoch 26, validation: 100%|██████████| 4/4 [00:00<00:00, 92.17it/s]
# [Epoch 26]
# Training - Log Prob: 3.9227
# Validation - Log Prob: 3.1916
# Current learning rates: [0.0005]
# Epoch 27, training: 100%|██████████| 32/32 [00:01<00:00, 27.13it/s]
# Epoch 27, validation: 100%|██████████| 4/4 [00:00<00:00, 94.35it/s]
# [Epoch 27]
# Training - Log Prob: 4.1678
# Validation - Log Prob: 3.8624
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 28, training: 100%|██████████| 32/32 [00:01<00:00, 27.23it/s]
# Epoch 28, validation: 100%|██████████| 4/4 [00:00<00:00, 98.92it/s]
# [Epoch 28]
# Training - Log Prob: 3.6850
# Validation - Log Prob: 2.7793
# Current learning rates: [0.0005]
# Epoch 29, training: 100%|██████████| 32/32 [00:01<00:00, 27.48it/s]
# Epoch 29, validation: 100%|██████████| 4/4 [00:00<00:00, 97.88it/s]
# [Epoch 29]
# Training - Log Prob: 3.6955
# Validation - Log Prob: 3.7609
# Current learning rates: [0.0005]
# Epoch 30, training: 100%|██████████| 32/32 [00:01<00:00, 28.69it/s]
# Epoch 30, validation: 100%|██████████| 4/4 [00:00<00:00, 94.84it/s]
# [Epoch 30]
# Training - Log Prob: 3.9671
# Validation - Log Prob: 3.8326
# Current learning rates: [0.0005]
# Epoch 31, training: 100%|██████████| 32/32 [00:01<00:00, 27.81it/s]
# Epoch 31, validation: 100%|██████████| 4/4 [00:00<00:00, 86.97it/s]
# [Epoch 31]
# Training - Log Prob: 3.4763
# Validation - Log Prob: 3.6533
# Current learning rates: [0.0005]
# Epoch 32, training: 100%|██████████| 32/32 [00:01<00:00, 27.70it/s]
# Epoch 32, validation: 100%|██████████| 4/4 [00:00<00:00, 84.07it/s]
# [Epoch 32]
# Training - Log Prob: 3.9493
# Validation - Log Prob: 3.7346
# Current learning rates: [0.0005]
# Epoch 33, training: 100%|██████████| 32/32 [00:01<00:00, 27.74it/s]
# Epoch 33, validation: 100%|██████████| 4/4 [00:00<00:00, 95.50it/s]
# [Epoch 33]
# Training - Log Prob: 4.2041
# Validation - Log Prob: 3.9093
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 34, training: 100%|██████████| 32/32 [00:01<00:00, 28.49it/s]
# Epoch 34, validation: 100%|██████████| 4/4 [00:00<00:00, 92.86it/s]
# [Epoch 34]
# Training - Log Prob: 4.0411
# Validation - Log Prob: 3.5048
# Current learning rates: [0.0005]
# Epoch 35, training: 100%|██████████| 32/32 [00:01<00:00, 27.81it/s]
# Epoch 35, validation: 100%|██████████| 4/4 [00:00<00:00, 99.52it/s]
# [Epoch 35]
# Training - Log Prob: 4.2489
# Validation - Log Prob: 3.9257
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 36, training: 100%|██████████| 32/32 [00:01<00:00, 23.95it/s]
# Epoch 36, validation: 100%|██████████| 4/4 [00:00<00:00, 97.68it/s]
# [Epoch 36]
# Training - Log Prob: 4.4713
# Validation - Log Prob: 4.0371
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 37, training: 100%|██████████| 32/32 [00:01<00:00, 28.86it/s]
# Epoch 37, validation: 100%|██████████| 4/4 [00:00<00:00, 89.00it/s]
# [Epoch 37]
# Training - Log Prob: 4.4707
# Validation - Log Prob: 3.8469
# Current learning rates: [0.0005]
# Epoch 38, training: 100%|██████████| 32/32 [00:01<00:00, 28.16it/s]
# Epoch 38, validation: 100%|██████████| 4/4 [00:00<00:00, 94.05it/s]
# [Epoch 38]
# Training - Log Prob: 3.7569
# Validation - Log Prob: 4.0918
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 39, training: 100%|██████████| 32/32 [00:01<00:00, 28.46it/s]
# Epoch 39, validation: 100%|██████████| 4/4 [00:00<00:00, 104.78it/s]
# [Epoch 39]
# Training - Log Prob: 3.5398
# Validation - Log Prob: 3.5470
# Current learning rates: [0.0005]
# Epoch 40, training: 100%|██████████| 32/32 [00:01<00:00, 27.53it/s]
# Epoch 40, validation: 100%|██████████| 4/4 [00:00<00:00, 96.50it/s]
# [Epoch 40]
# Training - Log Prob: 3.8957
# Validation - Log Prob: 3.6742
# Current learning rates: [0.0005]
# Epoch 41, training: 100%|██████████| 32/32 [00:01<00:00, 27.97it/s]
# Epoch 41, validation: 100%|██████████| 4/4 [00:00<00:00, 102.31it/s]
# [Epoch 41]
# Training - Log Prob: 4.3279
# Validation - Log Prob: 4.3473
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 42, training: 100%|██████████| 32/32 [00:01<00:00, 27.79it/s]
# Epoch 42, validation: 100%|██████████| 4/4 [00:00<00:00, 101.69it/s]
# [Epoch 42]
# Training - Log Prob: 4.6179
# Validation - Log Prob: 3.9635
# Current learning rates: [0.0005]
# Epoch 43, training: 100%|██████████| 32/32 [00:01<00:00, 27.65it/s]
# Epoch 43, validation: 100%|██████████| 4/4 [00:00<00:00, 87.69it/s]
# [Epoch 43]
# Training - Log Prob: 4.0453
# Validation - Log Prob: 3.7411
# Current learning rates: [0.0005]
# Epoch 44, training: 100%|██████████| 32/32 [00:01<00:00, 25.38it/s]
# Epoch 44, validation: 100%|██████████| 4/4 [00:00<00:00, 77.17it/s]
# [Epoch 44]
# Training - Log Prob: 4.0270
# Validation - Log Prob: 3.4859
# Current learning rates: [0.0005]
# Epoch 45, training: 100%|██████████| 32/32 [00:01<00:00, 26.84it/s]
# Epoch 45, validation: 100%|██████████| 4/4 [00:00<00:00, 94.07it/s]
# [Epoch 45]
# Training - Log Prob: 4.3293
# Validation - Log Prob: 3.7408
# Current learning rates: [0.0005]
# Epoch 46, training: 100%|██████████| 32/32 [00:01<00:00, 27.08it/s]
# Epoch 46, validation: 100%|██████████| 4/4 [00:00<00:00, 94.67it/s]
# [Epoch 46]
# Training - Log Prob: 4.3183
# Validation - Log Prob: 3.6486
# Current learning rates: [0.0005]
# Epoch 47, training: 100%|██████████| 32/32 [00:01<00:00, 28.46it/s]
# Epoch 47, validation: 100%|██████████| 4/4 [00:00<00:00, 95.59it/s]
# [Epoch 47]
# Training - Log Prob: 4.7491
# Validation - Log Prob: 4.3944
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 48, training: 100%|██████████| 32/32 [00:01<00:00, 27.45it/s]
# Epoch 48, validation: 100%|██████████| 4/4 [00:00<00:00, 90.08it/s]
# [Epoch 48]
# Training - Log Prob: 4.4771
# Validation - Log Prob: 4.0020
# Current learning rates: [0.0005]
# Epoch 49, training: 100%|██████████| 32/32 [00:01<00:00, 27.69it/s]
# Epoch 49, validation: 100%|██████████| 4/4 [00:00<00:00, 101.64it/s]
# [Epoch 49]
# Training - Log Prob: 4.5701
# Validation - Log Prob: 3.6873
# Current learning rates: [0.0005]
# Epoch 50, training: 100%|██████████| 32/32 [00:01<00:00, 27.35it/s]
# Epoch 50, validation: 100%|██████████| 4/4 [00:00<00:00, 99.84it/s]
# [Epoch 50]
# Training - Log Prob: 4.5830
# Validation - Log Prob: 4.4932
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 51, training: 100%|██████████| 32/32 [00:01<00:00, 28.19it/s]
# Epoch 51, validation: 100%|██████████| 4/4 [00:00<00:00, 101.76it/s]
# [Epoch 51]
# Training - Log Prob: 4.5488
# Validation - Log Prob: 3.6013
# Current learning rates: [0.0005]
# Epoch 52, training: 100%|██████████| 32/32 [00:01<00:00, 25.75it/s]
# Epoch 52, validation: 100%|██████████| 4/4 [00:00<00:00, 79.59it/s]
# [Epoch 52]
# Training - Log Prob: 4.7949
# Validation - Log Prob: 2.9899
# Current learning rates: [0.0005]
# Epoch 53, training: 100%|██████████| 32/32 [00:01<00:00, 27.06it/s]
# Epoch 53, validation: 100%|██████████| 4/4 [00:00<00:00, 88.08it/s]
# [Epoch 53]
# Training - Log Prob: 4.2793
# Validation - Log Prob: 3.5179
# Current learning rates: [0.0005]
# Epoch 54, training: 100%|██████████| 32/32 [00:01<00:00, 27.83it/s]
# Epoch 54, validation: 100%|██████████| 4/4 [00:00<00:00, 92.74it/s]
# [Epoch 54]
# Training - Log Prob: 4.1065
# Validation - Log Prob: 4.2026
# Current learning rates: [0.0005]
# Epoch 55, training: 100%|██████████| 32/32 [00:01<00:00, 28.13it/s]
# Epoch 55, validation: 100%|██████████| 4/4 [00:00<00:00, 96.17it/s]
# [Epoch 55]
# Training - Log Prob: 4.4007
# Validation - Log Prob: 4.2446
# Current learning rates: [0.0005]
# Epoch 56, training: 100%|██████████| 32/32 [00:01<00:00, 27.89it/s]
# Epoch 56, validation: 100%|██████████| 4/4 [00:00<00:00, 110.00it/s]
# [Epoch 56]
# Training - Log Prob: 5.0276
# Validation - Log Prob: 4.0787
# Current learning rates: [0.0005]
# Epoch 57, training: 100%|██████████| 32/32 [00:01<00:00, 27.81it/s]
# Epoch 57, validation: 100%|██████████| 4/4 [00:00<00:00, 90.95it/s]
# [Epoch 57]
# Training - Log Prob: 5.2704
# Validation - Log Prob: 4.1847
# Current learning rates: [0.0005]
# Epoch 58, training: 100%|██████████| 32/32 [00:01<00:00, 27.54it/s]
# Epoch 58, validation: 100%|██████████| 4/4 [00:00<00:00, 90.69it/s]
# [Epoch 58]
# Training - Log Prob: 4.9777
# Validation - Log Prob: 3.9676
# Current learning rates: [0.0005]
# Epoch 59, training: 100%|██████████| 32/32 [00:01<00:00, 26.31it/s]
# Epoch 59, validation: 100%|██████████| 4/4 [00:00<00:00, 99.55it/s]
# [Epoch 59]
# Training - Log Prob: 4.6847
# Validation - Log Prob: 4.2027
# Current learning rates: [0.00025]
# Epoch 60, training: 100%|██████████| 32/32 [00:01<00:00, 27.63it/s]
# Epoch 60, validation: 100%|██████████| 4/4 [00:00<00:00, 89.82it/s]
# [Epoch 60]
# Training - Log Prob: 5.9575
# Validation - Log Prob: 4.6983
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 61, training: 100%|██████████| 32/32 [00:01<00:00, 27.01it/s]
# Epoch 61, validation: 100%|██████████| 4/4 [00:00<00:00, 92.38it/s]
# [Epoch 61]
# Training - Log Prob: 6.3296
# Validation - Log Prob: 4.9488
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 62, training: 100%|██████████| 32/32 [00:01<00:00, 25.04it/s]
# Epoch 62, validation: 100%|██████████| 4/4 [00:00<00:00, 96.81it/s]
# [Epoch 62]
# Training - Log Prob: 6.5968
# Validation - Log Prob: 4.7849
# Current learning rates: [0.00025]
# Epoch 63, training: 100%|██████████| 32/32 [00:01<00:00, 27.89it/s]
# Epoch 63, validation: 100%|██████████| 4/4 [00:00<00:00, 99.35it/s]
# [Epoch 63]
# Training - Log Prob: 6.6464
# Validation - Log Prob: 4.6870
# Current learning rates: [0.00025]
# Epoch 64, training: 100%|██████████| 32/32 [00:01<00:00, 27.58it/s]
# Epoch 64, validation: 100%|██████████| 4/4 [00:00<00:00, 103.31it/s]
# [Epoch 64]
# Training - Log Prob: 6.7111
# Validation - Log Prob: 4.5387
# Current learning rates: [0.00025]
# Epoch 65, training: 100%|██████████| 32/32 [00:01<00:00, 28.43it/s]
# Epoch 65, validation: 100%|██████████| 4/4 [00:00<00:00, 99.47it/s]
# [Epoch 65]
# Training - Log Prob: 6.6699
# Validation - Log Prob: 4.4869
# Current learning rates: [0.00025]
# Epoch 66, training: 100%|██████████| 32/32 [00:01<00:00, 27.06it/s]
# Epoch 66, validation: 100%|██████████| 4/4 [00:00<00:00, 83.11it/s]
# [Epoch 66]
# Training - Log Prob: 6.6185
# Validation - Log Prob: 4.5990
# Current learning rates: [0.00025]
# Epoch 67, training: 100%|██████████| 32/32 [00:01<00:00, 27.55it/s]
# Epoch 67, validation: 100%|██████████| 4/4 [00:00<00:00, 86.67it/s]
# [Epoch 67]
# Training - Log Prob: 6.4469
# Validation - Log Prob: 4.5234
# Current learning rates: [0.00025]
# Epoch 68, training: 100%|██████████| 32/32 [00:01<00:00, 28.25it/s]
# Epoch 68, validation: 100%|██████████| 4/4 [00:00<00:00, 97.01it/s]
# [Epoch 68]
# Training - Log Prob: 6.3406
# Validation - Log Prob: 4.5481
# Current learning rates: [0.00025]
# Epoch 69, training: 100%|██████████| 32/32 [00:01<00:00, 25.96it/s]
# Epoch 69, validation: 100%|██████████| 4/4 [00:00<00:00, 90.45it/s]
# [Epoch 69]
# Training - Log Prob: 6.6536
# Validation - Log Prob: 5.0352
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 70, training: 100%|██████████| 32/32 [00:01<00:00, 28.33it/s]
# Epoch 70, validation: 100%|██████████| 4/4 [00:00<00:00, 93.50it/s]
# [Epoch 70]
# Training - Log Prob: 7.0169
# Validation - Log Prob: 4.7649
# Current learning rates: [0.00025]
# Epoch 71, training: 100%|██████████| 32/32 [00:01<00:00, 27.29it/s]
# Epoch 71, validation: 100%|██████████| 4/4 [00:00<00:00, 90.17it/s]
# [Epoch 71]
# Training - Log Prob: 6.6740
# Validation - Log Prob: 4.9038
# Current learning rates: [0.00025]
# Epoch 72, training: 100%|██████████| 32/32 [00:01<00:00, 27.68it/s]
# Epoch 72, validation: 100%|██████████| 4/4 [00:00<00:00, 95.51it/s]
# [Epoch 72]
# Training - Log Prob: 6.6639
# Validation - Log Prob: 5.1567
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to best_npe_model.pt
# Epoch 73, training: 100%|██████████| 32/32 [00:01<00:00, 27.44it/s]
# Epoch 73, validation: 100%|██████████| 4/4 [00:00<00:00, 102.53it/s]
# [Epoch 73]
# Training - Log Prob: 6.7283
# Validation - Log Prob: 4.4373
# Current learning rates: [0.00025]
# Epoch 74, training: 100%|██████████| 32/32 [00:01<00:00, 27.51it/s]
# Epoch 74, validation: 100%|██████████| 4/4 [00:00<00:00, 90.78it/s]
# [Epoch 74]
# Training - Log Prob: 6.1972
# Validation - Log Prob: 4.5492
# Current learning rates: [0.00025]
# Epoch 75, training: 100%|██████████| 32/32 [00:01<00:00, 25.89it/s]
# Epoch 75, validation: 100%|██████████| 4/4 [00:00<00:00, 95.78it/s]
# [Epoch 75]
# Training - Log Prob: 6.4741
# Validation - Log Prob: 4.8168
# Current learning rates: [0.00025]
# Epoch 76, training: 100%|██████████| 32/32 [00:01<00:00, 26.77it/s]
# Epoch 76, validation: 100%|██████████| 4/4 [00:00<00:00, 89.32it/s]
# [Epoch 76]
# Training - Log Prob: 6.8111
# Validation - Log Prob: 4.4172
# Current learning rates: [0.00025]
# Epoch 77, training: 100%|██████████| 32/32 [00:01<00:00, 26.61it/s]
# Epoch 77, validation: 100%|██████████| 4/4 [00:00<00:00, 94.20it/s]
# [Epoch 77]
# Training - Log Prob: 6.8144
# Validation - Log Prob: 4.5808
# Current learning rates: [0.00025]
# Epoch 78, training: 100%|██████████| 32/32 [00:01<00:00, 27.62it/s]
# Epoch 78, validation: 100%|██████████| 4/4 [00:00<00:00, 99.18it/s]
# [Epoch 78]
# Training - Log Prob: 7.1073
# Validation - Log Prob: 4.4522
# Current learning rates: [0.00025]
# Epoch 79, training: 100%|██████████| 32/32 [00:01<00:00, 27.59it/s]
# Epoch 79, validation: 100%|██████████| 4/4 [00:00<00:00, 104.76it/s]
# [Epoch 79]
# Training - Log Prob: 7.1104
# Validation - Log Prob: 4.4465
# Current learning rates: [0.00025]
# Epoch 80, training: 100%|██████████| 32/32 [00:01<00:00, 27.74it/s]
# Epoch 80, validation: 100%|██████████| 4/4 [00:00<00:00, 96.68it/s]
# [Epoch 80]
# Training - Log Prob: 7.1109
# Validation - Log Prob: 4.2746
# Current learning rates: [0.00025]
# Epoch 81, training: 100%|██████████| 32/32 [00:01<00:00, 25.67it/s]
# Epoch 81, validation: 100%|██████████| 4/4 [00:00<00:00, 90.39it/s]
# [Epoch 81]
# Training - Log Prob: 6.7919
# Validation - Log Prob: 4.5905
# Current learning rates: [0.000125]
# Epoch 82, training: 100%|██████████| 32/32 [00:01<00:00, 26.22it/s]
# Epoch 82, validation: 100%|██████████| 4/4 [00:00<00:00, 92.12it/s]
# [Epoch 82]
# Training - Log Prob: 7.4456
# Validation - Log Prob: 4.5465
# Current learning rates: [0.000125]
# Epoch 83, training: 100%|██████████| 32/32 [00:01<00:00, 25.41it/s]
# Epoch 83, validation: 100%|██████████| 4/4 [00:00<00:00, 85.71it/s]
# [Epoch 83]
# Training - Log Prob: 7.8498
# Validation - Log Prob: 4.0213
# Current learning rates: [0.000125]
# Epoch 84, training: 100%|██████████| 32/32 [00:01<00:00, 26.30it/s]
# Epoch 84, validation: 100%|██████████| 4/4 [00:00<00:00, 98.51it/s]
# [Epoch 84]
# Training - Log Prob: 7.9815
# Validation - Log Prob: 3.9841
# Current learning rates: [0.000125]
# Epoch 85, training: 100%|██████████| 32/32 [00:01<00:00, 27.71it/s]
# Epoch 85, validation: 100%|██████████| 4/4 [00:00<00:00, 95.45it/s]
# [Epoch 85]
# Training - Log Prob: 8.1143
# Validation - Log Prob: 3.7653
# Current learning rates: [0.000125]
# Epoch 86, training: 100%|██████████| 32/32 [00:01<00:00, 25.53it/s]
# Epoch 86, validation: 100%|██████████| 4/4 [00:00<00:00, 83.25it/s]
# [Epoch 86]
# Training - Log Prob: 8.0313
# Validation - Log Prob: 3.4380
# Current learning rates: [0.000125]
# Epoch 87, training: 100%|██████████| 32/32 [00:01<00:00, 25.67it/s]
# Epoch 87, validation: 100%|██████████| 4/4 [00:00<00:00, 93.59it/s]
# [Epoch 87]
# Training - Log Prob: 8.0806
# Validation - Log Prob: 3.1778
# Current learning rates: [0.000125]
# Epoch 88, training: 100%|██████████| 32/32 [00:01<00:00, 27.32it/s]
# Epoch 88, validation: 100%|██████████| 4/4 [00:00<00:00, 93.68it/s]
# [Epoch 88]
# Training - Log Prob: 8.1897
# Validation - Log Prob: 3.3942
# Current learning rates: [0.000125]
# Epoch 89, training: 100%|██████████| 32/32 [00:01<00:00, 24.41it/s]
# Epoch 89, validation: 100%|██████████| 4/4 [00:00<00:00, 84.72it/s]
# [Epoch 89]
# Training - Log Prob: 8.1859
# Validation - Log Prob: 3.1888
# Current learning rates: [0.000125]
# Epoch 90, training: 100%|██████████| 32/32 [00:01<00:00, 17.74it/s]
# Epoch 90, validation: 100%|██████████| 4/4 [00:00<00:00, 66.66it/s]
# [Epoch 90]
# Training - Log Prob: 8.0938
# Validation - Log Prob: 2.9877
# Current learning rates: [6.25e-05]
# Epoch 91, training: 100%|██████████| 32/32 [00:01<00:00, 21.43it/s]
# Epoch 91, validation: 100%|██████████| 4/4 [00:00<00:00, 68.48it/s]
# [Epoch 91]
# Training - Log Prob: 8.3444
# Validation - Log Prob: 3.4586
# Current learning rates: [6.25e-05]
# Epoch 92, training: 100%|██████████| 32/32 [00:01<00:00, 22.35it/s]
# Epoch 92, validation: 100%|██████████| 4/4 [00:00<00:00, 89.97it/s]
# [Epoch 92]
# Training - Log Prob: 8.6850
# Validation - Log Prob: 3.0678
# Current learning rates: [6.25e-05]
# No improvement in validation log prob in last 20 epochs

# %%
plt.figure(figsize=(10, 5))
plt.plot(training_stuff['train_log_probs'], linewidth=2, label='Train Log Probability')
plt.plot(training_stuff['val_log_probs'], linewidth=2, label='Validation Log Probability')
plt.legend(fontsize=12)
plt.title('NPE Model Training Progress: Log Probability', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Log Probability')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Taken from old stuff and updated w claude and myself
from matplotlib.patches import Rectangle # Rectangle where both axes' 1-sigma regions overlap

model, _ = load_npe("Dingo.pt")

# Test on several different true frequencies, phases, and amplitudes
test_frequencies = [1.0, 2.5, 4.0]
test_phases = [0.5, -0.3, 1.2]
test_amplitudes = [1.0, 0.8, 2.4]

fig, axes = plt.subplots(7, len(test_frequencies), figsize=(8*len(test_frequencies), 40))

print("Testing NPE model on new observations:\n")

for idx, true_freq in enumerate(test_frequencies):
    true_phase = test_phases[idx]
    true_amp = test_amplitudes[idx]
    print(f"\nTest {idx+1}: True Frequency = {true_freq}, True Phase = {true_phase:.2f}, True Amplitude = {true_amp:.2f}")
    
    # Generate new observation
    observed_data = simulate_sine_wave(true_freq, phase=true_phase, amplitude=true_amp)
    
    # Infer posterior
    posterior_samples, stats = infer_NPE(model, observed_data, num_samples=5000)
    
    # Handle both 1D and 2D cases for posterior samples
    if len(posterior_samples.shape) == 1:
        # 1D case - shouldn't happen with 3 params
        amp_samples = posterior_samples
        freq_samples = posterior_samples
        phase_samples = posterior_samples
    else:
        # 2D case [num_samples, 3] with [amplitude, frequency, phase]
        amp_samples = posterior_samples[:, 0]
        freq_samples = posterior_samples[:, 1]
        phase_samples = posterior_samples[:, 2]
    
    freq_stats = {
        'mean': np.mean(freq_samples),
        'median': np.median(freq_samples),
        'std': np.std(freq_samples),
        'q05': np.percentile(freq_samples, 5),
        'q95': np.percentile(freq_samples, 95),
    }
    
    phase_stats = {
        'mean': np.mean(phase_samples),
        'median': np.median(phase_samples),
        'std': np.std(phase_samples),
        'q05': np.percentile(phase_samples, 5),
        'q95': np.percentile(phase_samples, 95),
    }
    
    amp_stats = {
        'mean': np.mean(amp_samples),
        'median': np.median(amp_samples),
        'std': np.std(amp_samples),
        'q05': np.percentile(amp_samples, 5),
        'q95': np.percentile(amp_samples, 95),
    }
    
    parameters = ['amplitude', 'frequency', 'phase']
    ps = ['A', 'f', 'φ']
    samples_list = [amp_samples, freq_samples, phase_samples]
    stats_list = [amp_stats, freq_stats, phase_stats]
    true_list = [true_amp, true_freq, true_phase]

    print(f"  Frequency posterior: mean={freq_stats['mean']:.3f} ± {freq_stats['std']:.3f}")
    print(f"  Phase posterior:     mean={phase_stats['mean']:.3f} ± {phase_stats['std']:.3f}")
    print(f"  Amplitude posterior: mean={amp_stats['mean']:.3f} ± {amp_stats['std']:.3f}")
    
    t = np.linspace(0, 6*np.pi, 1000)

    # Plot observed data
    axes[0, idx].plot(t, observed_data, 'b-', alpha=0.7, linewidth=1.5, label='Observed')
    axes[0, idx].plot(t, true_amp * np.sin(2*np.pi*true_freq * t + true_phase), 'r--', 
                      label=f'True (f={true_freq}, φ={true_phase:.2f}, A={true_amp:.2f})', linewidth=2)
    axes[0, idx].set_title(f'Test {idx+1}: f={true_freq}, φ={true_phase:.2f}, A={true_amp:.2f}', fontsize=12, fontweight='bold')
    axes[0, idx].set_xlabel('Time')
    axes[0, idx].set_ylabel('Value')
    axes[0, idx].legend(fontsize=8)
    axes[0, idx].grid(True, alpha=0.3)

    for idx2, _ in enumerate(parameters):
        axes[idx2 + 1, idx].hist(samples_list[idx2], bins=60, density=True, 
                      alpha=0.6, edgecolor='black', label='Posterior')
        axes[idx2 + 1, idx].axvline(true_list[idx2], color='red', linestyle='--', 
                             linewidth=2.5, label=f'True: {true_list[idx2]:.2f}', zorder=10)
        axes[idx2 + 1, idx].axvline(stats_list[idx2]['mean'], color='green', linestyle='-', 
                             linewidth=2.5, label=f"Mean: {stats_list[idx2]['mean']:.2f}", zorder=10)
        axes[idx2 + 1, idx].axvspan(stats_list[idx2]['q05'], stats_list[idx2]['q95'], alpha=0.2, color='gray', label='90% CI')
        axes[idx2 + 1, idx].set_title(f'p({parameters[idx2]} | data)', fontsize=12, fontweight='bold')
        axes[idx2 + 1, idx].set_xlabel(parameters[idx2].capitalize())
        axes[idx2 + 1, idx].set_ylabel('Density')
        axes[idx2 + 1, idx].legend(loc='upper right', fontsize=8)
        axes[idx2 + 1, idx].grid(True, alpha=0.3)

    for idx2, _ in enumerate(parameters):
        # 2D histograms for parameter pairs
        h = axes[len(parameters) + idx2 + 1, idx].hist2d(samples_list[idx2], samples_list[(idx2+1) % 3], bins=60, cmap='plasma', density=True)
        plt.colorbar(h[3], ax=axes[len(parameters) + idx2 + 1, idx], label='Probability Density')
        axes[len(parameters) + idx2 + 1, idx].scatter(true_list[idx2], true_list[(idx2+1) % 3], color='cyan', s=200, marker='x',  
                            edgecolors='white', linewidth=2, label='True values', zorder=10) # Plot true values
        axes[len(parameters) + idx2 + 1, idx].scatter(stats_list[idx2]['mean'], stats_list[(idx2+1) % 3]['mean'], color='lime', s=100, marker='o', 
                            linewidth=3, label='Posterior mean', zorder=10) # Plot mean

        rect = Rectangle((stats_list[idx2]['mean'] - stats_list[idx2]['std'], stats_list[(idx2+1) % 3]['mean'] - stats_list[(idx2+1) % 3]['std']), 
                        width=2*stats_list[idx2]['std'], height=2*stats_list[(idx2+1) % 3]['std'],
                        facecolor='yellow', edgecolor='yellow', linewidth=2, 
                        alpha=0.3, label='1σ region', zorder=5)
        
        axes[len(parameters) + idx2 + 1, idx].add_patch(rect)
        axes[len(parameters) + idx2 + 1, idx].set_xlabel(parameters[idx2], fontsize=12, fontweight='bold')
        axes[len(parameters) + idx2 + 1, idx].set_ylabel(parameters[(idx2+1) % 3], fontsize=12, fontweight='bold')
        axes[len(parameters) + idx2 + 1, idx].set_title(f'Joint Posterior p({ps[idx2]}, {ps[(idx2+1) % 3]} | data)\nTrue: {ps[idx2]}={true_list[idx2]}, {ps[(idx2+1) % 3]}={true_list[(idx2+1) % 3]}', fontsize=12, fontweight='bold')
        axes[len(parameters) + idx2 + 1, idx].legend(loc='upper right', fontsize=8)
        axes[len(parameters) + idx2 + 1, idx].grid(True, alpha=0.3)

    
plt.tight_layout()
plt.show()
# Out:
# Loaded DINGOModel from Dingo.pt
#   Best epoch: 190
#   Best validation log prob: 8.1046
# Testing NPE model on new observations:
#
#
# Test 1: True Frequency = 1.0, True Phase = 0.50, True Amplitude = 1.00
#   Frequency posterior: mean=0.981 ± 0.007
#   Phase posterior:     mean=0.546 ± 0.031
#   Amplitude posterior: mean=0.991 ± 0.012
#
# Test 2: True Frequency = 2.5, True Phase = -0.30, True Amplitude = 0.80
# /tmp/ipykernel_92456/2181378104.py:102: UserWarning: You passed a edgecolor/edgecolors ('white') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   axes[len(parameters) + idx2 + 1, idx].scatter(true_list[idx2], true_list[(idx2+1) % 3], color='cyan', s=200, marker='x',
#   Frequency posterior: mean=2.513 ± 0.014
#   Phase posterior:     mean=-0.300 ± 0.036
#   Amplitude posterior: mean=0.793 ± 0.010
#
# Test 3: True Frequency = 4.0, True Phase = 1.20, True Amplitude = 2.40
#   Frequency posterior: mean=3.989 ± 0.014
#   Phase posterior:     mean=1.207 ± 0.013
#   Amplitude posterior: mean=2.406 ± 0.011

# %% [markdown]
# # TODO FOR JHPY
# DONT MARK ANYTHING DONE UNTIL YOU ARE SURE IT WORKS YA DUMMY
#
#
# - Combine Sin functions --> Done
# - Layers --> Done
# - Models --> Done
# - get all Neural Network Functions working
#     - Training function
#         - Data --> Done
#         - Loss --> Done
#         - Dropout + add to predictor --> Done
#         - Gradient Clipping --> Done
#     - Models should take config to allow param search
#     - convert DINGOmodel to just be a specific config
# - Create custom model to test things
# - Get claude to check all docstrings

# %% [markdown]
# # Dev ground
