# %% [markdown]
# # Full npe with context

# %%
from JHPY import *
import matplotlib.pyplot as plt

# %%
outputs = generate_sine_data(num_simulations=75000, batch_size=2048)
# Out:
# generating 75000 samples for training
# data generated

# %%
config = {
            'data_dim': 1000,
            'param_dim': 3,
            'context_dim': 128,
            'num_flow_layers': 10,
            'hidden_dim': 256,
        }

model = DINGOModel(config=config)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.5, patience=6
)

training_stuff = train_npe_model(model, optimizer, 300, outputs["Train_Loader"], outputs["Val_Loader"], scheduler=scheduler, patience=18, dropout_rate=0.1, save_best_model=True, model_path="Dingo.pt")
# Out:
# Epoch 1, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 1, validation: 100%|██████████| 4/4 [00:00<00:00, 13.73it/s]
# [Epoch  1]
# Training - Log Prob: -5.1532
# Validation - Log Prob: -3.8395
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 2, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 2, validation: 100%|██████████| 4/4 [00:00<00:00, 13.29it/s]
# [Epoch  2]
# Training - Log Prob: -3.8754
# Validation - Log Prob: -2.2136
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 3, training: 100%|██████████| 30/30 [00:07<00:00,  4.26it/s]
# Epoch 3, validation: 100%|██████████| 4/4 [00:00<00:00, 13.81it/s]
# [Epoch  3]
# Training - Log Prob: -2.4143
# Validation - Log Prob: -1.2878
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 4, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 4, validation: 100%|██████████| 4/4 [00:00<00:00,  8.27it/s]
# [Epoch  4]
# Training - Log Prob: -1.2247
# Validation - Log Prob: -0.3827
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 5, training: 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# Epoch 5, validation: 100%|██████████| 4/4 [00:00<00:00, 13.45it/s]
# [Epoch  5]
# Training - Log Prob: -0.3605
# Validation - Log Prob: 0.5694
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 6, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 6, validation: 100%|██████████| 4/4 [00:00<00:00, 13.65it/s]
# [Epoch  6]
# Training - Log Prob: -0.4516
# Validation - Log Prob: 0.1017
# Current learning rates: [0.0005]
# Epoch 7, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 7, validation: 100%|██████████| 4/4 [00:00<00:00, 14.33it/s]
# [Epoch  7]
# Training - Log Prob: -0.1764
# Validation - Log Prob: 0.2391
# Current learning rates: [0.0005]
# Epoch 8, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 8, validation: 100%|██████████| 4/4 [00:00<00:00, 14.11it/s]
# [Epoch  8]
# Training - Log Prob: 0.5318
# Validation - Log Prob: -4.0052
# Current learning rates: [0.0005]
# Epoch 9, training: 100%|██████████| 30/30 [00:06<00:00,  4.31it/s]
# Epoch 9, validation: 100%|██████████| 4/4 [00:00<00:00,  9.15it/s]
# [Epoch  9]
# Training - Log Prob: 0.1983
# Validation - Log Prob: 1.0558
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 10, training: 100%|██████████| 30/30 [00:07<00:00,  4.09it/s]
# Epoch 10, validation: 100%|██████████| 4/4 [00:00<00:00, 13.29it/s]
# [Epoch 10]
# Training - Log Prob: 1.8170
# Validation - Log Prob: 2.2323
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 11, training: 100%|██████████| 30/30 [00:06<00:00,  4.34it/s]
# Epoch 11, validation: 100%|██████████| 4/4 [00:00<00:00, 14.27it/s]
# [Epoch 11]
# Training - Log Prob: 2.6862
# Validation - Log Prob: 3.1650
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 12, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 12, validation: 100%|██████████| 4/4 [00:00<00:00, 13.80it/s]
# [Epoch 12]
# Training - Log Prob: 2.6124
# Validation - Log Prob: 3.1363
# Current learning rates: [0.0005]
# Epoch 13, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 13, validation: 100%|██████████| 4/4 [00:00<00:00, 14.27it/s]
# [Epoch 13]
# Training - Log Prob: 2.3809
# Validation - Log Prob: 2.8625
# Current learning rates: [0.0005]
# Epoch 14, training: 100%|██████████| 30/30 [00:06<00:00,  4.30it/s]
# Epoch 14, validation: 100%|██████████| 4/4 [00:00<00:00,  9.25it/s]
# [Epoch 14]
# Training - Log Prob: 2.7287
# Validation - Log Prob: 3.5701
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 15, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 15, validation: 100%|██████████| 4/4 [00:00<00:00, 13.75it/s]
# [Epoch 15]
# Training - Log Prob: 2.4368
# Validation - Log Prob: 1.5391
# Current learning rates: [0.0005]
# Epoch 16, training: 100%|██████████| 30/30 [00:06<00:00,  4.30it/s]
# Epoch 16, validation: 100%|██████████| 4/4 [00:00<00:00, 12.92it/s]
# [Epoch 16]
# Training - Log Prob: 2.7259
# Validation - Log Prob: 3.3613
# Current learning rates: [0.0005]
# Epoch 17, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 17, validation: 100%|██████████| 4/4 [00:00<00:00, 13.35it/s]
# [Epoch 17]
# Training - Log Prob: 3.4429
# Validation - Log Prob: 3.8522
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 18, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 18, validation: 100%|██████████| 4/4 [00:00<00:00, 13.47it/s]
# [Epoch 18]
# Training - Log Prob: 3.0353
# Validation - Log Prob: 3.5969
# Current learning rates: [0.0005]
# Epoch 19, training: 100%|██████████| 30/30 [00:07<00:00,  4.10it/s]
# Epoch 19, validation: 100%|██████████| 4/4 [00:00<00:00, 13.59it/s]
# [Epoch 19]
# Training - Log Prob: 3.5240
# Validation - Log Prob: 4.0485
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 20, training: 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# Epoch 20, validation: 100%|██████████| 4/4 [00:00<00:00,  8.83it/s]
# [Epoch 20]
# Training - Log Prob: 2.7519
# Validation - Log Prob: 3.6803
# Current learning rates: [0.0005]
# Epoch 21, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 21, validation: 100%|██████████| 4/4 [00:00<00:00, 13.44it/s]
# [Epoch 21]
# Training - Log Prob: 2.8817
# Validation - Log Prob: 3.5292
# Current learning rates: [0.0005]
# Epoch 22, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 22, validation: 100%|██████████| 4/4 [00:00<00:00, 13.06it/s]
# [Epoch 22]
# Training - Log Prob: 3.7660
# Validation - Log Prob: 4.0958
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 23, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 23, validation: 100%|██████████| 4/4 [00:00<00:00, 14.15it/s]
# [Epoch 23]
# Training - Log Prob: 4.4034
# Validation - Log Prob: 4.6114
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 24, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 24, validation: 100%|██████████| 4/4 [00:00<00:00, 13.54it/s]
# [Epoch 24]
# Training - Log Prob: 4.1928
# Validation - Log Prob: 3.2508
# Current learning rates: [0.0005]
# Epoch 25, training: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# Epoch 25, validation: 100%|██████████| 4/4 [00:00<00:00, 13.08it/s]
# [Epoch 25]
# Training - Log Prob: 3.9157
# Validation - Log Prob: 3.8352
# Current learning rates: [0.0005]
# Epoch 26, training: 100%|██████████| 30/30 [00:07<00:00,  3.97it/s]
# Epoch 26, validation: 100%|██████████| 4/4 [00:00<00:00, 13.58it/s]
# [Epoch 26]
# Training - Log Prob: 3.7791
# Validation - Log Prob: 2.2059
# Current learning rates: [0.0005]
# Epoch 27, training: 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# Epoch 27, validation: 100%|██████████| 4/4 [00:00<00:00, 13.35it/s]
# [Epoch 27]
# Training - Log Prob: 3.1249
# Validation - Log Prob: 4.3001
# Current learning rates: [0.0005]
# Epoch 28, training: 100%|██████████| 30/30 [00:07<00:00,  4.05it/s]
# Epoch 28, validation: 100%|██████████| 4/4 [00:00<00:00, 14.04it/s]
# [Epoch 28]
# Training - Log Prob: 4.3103
# Validation - Log Prob: 4.4632
# Current learning rates: [0.0005]
# Epoch 29, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 29, validation: 100%|██████████| 4/4 [00:00<00:00, 13.24it/s]
# [Epoch 29]
# Training - Log Prob: 3.3266
# Validation - Log Prob: 3.9283
# Current learning rates: [0.0005]
# Epoch 30, training: 100%|██████████| 30/30 [00:07<00:00,  4.06it/s]
# Epoch 30, validation: 100%|██████████| 4/4 [00:00<00:00, 13.44it/s]
# [Epoch 30]
# Training - Log Prob: 4.3687
# Validation - Log Prob: 4.6683
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 31, training: 100%|██████████| 30/30 [00:07<00:00,  4.00it/s]
# Epoch 31, validation: 100%|██████████| 4/4 [00:00<00:00, 12.33it/s]
# [Epoch 31]
# Training - Log Prob: 2.7356
# Validation - Log Prob: 1.7339
# Current learning rates: [0.0005]
# Epoch 32, training: 100%|██████████| 30/30 [00:07<00:00,  4.04it/s]
# Epoch 32, validation: 100%|██████████| 4/4 [00:00<00:00,  8.97it/s]
# [Epoch 32]
# Training - Log Prob: 3.7864
# Validation - Log Prob: 4.4452
# Current learning rates: [0.0005]
# Epoch 33, training: 100%|██████████| 30/30 [00:07<00:00,  4.07it/s]
# Epoch 33, validation: 100%|██████████| 4/4 [00:00<00:00, 13.31it/s]
# [Epoch 33]
# Training - Log Prob: 4.6094
# Validation - Log Prob: 5.0498
# Current learning rates: [0.0005]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 34, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 34, validation: 100%|██████████| 4/4 [00:00<00:00, 13.59it/s]
# [Epoch 34]
# Training - Log Prob: 3.4799
# Validation - Log Prob: 5.0177
# Current learning rates: [0.0005]
# Epoch 35, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 35, validation: 100%|██████████| 4/4 [00:00<00:00, 13.39it/s]
# [Epoch 35]
# Training - Log Prob: 4.1156
# Validation - Log Prob: 3.6649
# Current learning rates: [0.0005]
# Epoch 36, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 36, validation: 100%|██████████| 4/4 [00:00<00:00, 13.79it/s]
# [Epoch 36]
# Training - Log Prob: 4.8297
# Validation - Log Prob: 4.7122
# Current learning rates: [0.0005]
# Epoch 37, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 37, validation: 100%|██████████| 4/4 [00:00<00:00, 14.08it/s]
# [Epoch 37]
# Training - Log Prob: 3.6886
# Validation - Log Prob: 4.3781
# Current learning rates: [0.0005]
# Epoch 38, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 38, validation: 100%|██████████| 4/4 [00:00<00:00, 13.74it/s]
# [Epoch 38]
# Training - Log Prob: 4.0856
# Validation - Log Prob: 3.7751
# Current learning rates: [0.0005]
# Epoch 39, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 39, validation: 100%|██████████| 4/4 [00:00<00:00, 13.53it/s]
# [Epoch 39]
# Training - Log Prob: 4.5792
# Validation - Log Prob: 4.9435
# Current learning rates: [0.0005]
# Epoch 40, training: 100%|██████████| 30/30 [00:07<00:00,  3.97it/s]
# Epoch 40, validation: 100%|██████████| 4/4 [00:00<00:00, 13.65it/s]
# [Epoch 40]
# Training - Log Prob: 5.0366
# Validation - Log Prob: 4.9876
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [0.00025]
# Epoch 41, training: 100%|██████████| 30/30 [00:07<00:00,  4.07it/s]
# Epoch 41, validation: 100%|██████████| 4/4 [00:00<00:00, 14.34it/s]
# [Epoch 41]
# Training - Log Prob: 5.5404
# Validation - Log Prob: 5.5068
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 42, training: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# Epoch 42, validation: 100%|██████████| 4/4 [00:00<00:00, 13.81it/s]
# [Epoch 42]
# Training - Log Prob: 5.7700
# Validation - Log Prob: 5.4267
# Current learning rates: [0.00025]
# Epoch 43, training: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# Epoch 43, validation: 100%|██████████| 4/4 [00:00<00:00, 13.94it/s]
# [Epoch 43]
# Training - Log Prob: 5.8606
# Validation - Log Prob: 5.6769
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 44, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 44, validation: 100%|██████████| 4/4 [00:00<00:00, 13.26it/s]
# [Epoch 44]
# Training - Log Prob: 6.0080
# Validation - Log Prob: 5.8265
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 45, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 45, validation: 100%|██████████| 4/4 [00:00<00:00, 13.43it/s]
# [Epoch 45]
# Training - Log Prob: 6.1335
# Validation - Log Prob: 5.8027
# Current learning rates: [0.00025]
# Epoch 46, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 46, validation: 100%|██████████| 4/4 [00:00<00:00, 13.20it/s]
# [Epoch 46]
# Training - Log Prob: 6.1804
# Validation - Log Prob: 4.6897
# Current learning rates: [0.00025]
# Epoch 47, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 47, validation: 100%|██████████| 4/4 [00:00<00:00,  9.31it/s]
# [Epoch 47]
# Training - Log Prob: 5.1924
# Validation - Log Prob: 5.7490
# Current learning rates: [0.00025]
# Epoch 48, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 48, validation: 100%|██████████| 4/4 [00:00<00:00, 13.51it/s]
# [Epoch 48]
# Training - Log Prob: 5.6418
# Validation - Log Prob: 5.0123
# Current learning rates: [0.00025]
# Epoch 49, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 49, validation: 100%|██████████| 4/4 [00:00<00:00, 13.72it/s]
# [Epoch 49]
# Training - Log Prob: 5.9342
# Validation - Log Prob: 5.8733
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 50, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 50, validation: 100%|██████████| 4/4 [00:00<00:00, 14.29it/s]
# [Epoch 50]
# Training - Log Prob: 6.2089
# Validation - Log Prob: 5.9939
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 51, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 51, validation: 100%|██████████| 4/4 [00:00<00:00, 13.52it/s]
# [Epoch 51]
# Training - Log Prob: 6.4160
# Validation - Log Prob: 6.0201
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 52, training: 100%|██████████| 30/30 [00:06<00:00,  4.30it/s]
# Epoch 52, validation: 100%|██████████| 4/4 [00:00<00:00, 13.70it/s]
# [Epoch 52]
# Training - Log Prob: 6.1783
# Validation - Log Prob: 5.8692
# Current learning rates: [0.00025]
# Epoch 53, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 53, validation: 100%|██████████| 4/4 [00:00<00:00, 14.17it/s]
# [Epoch 53]
# Training - Log Prob: 5.9710
# Validation - Log Prob: 5.8493
# Current learning rates: [0.00025]
# Epoch 54, training: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# Epoch 54, validation: 100%|██████████| 4/4 [00:00<00:00, 13.90it/s]
# [Epoch 54]
# Training - Log Prob: 6.1204
# Validation - Log Prob: 6.0891
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 55, training: 100%|██████████| 30/30 [00:06<00:00,  4.32it/s]
# Epoch 55, validation: 100%|██████████| 4/4 [00:00<00:00,  9.46it/s]
# [Epoch 55]
# Training - Log Prob: 6.5031
# Validation - Log Prob: 6.1254
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 56, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 56, validation: 100%|██████████| 4/4 [00:00<00:00, 13.36it/s]
# [Epoch 56]
# Training - Log Prob: 6.3104
# Validation - Log Prob: 6.2208
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 57, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 57, validation: 100%|██████████| 4/4 [00:00<00:00, 12.98it/s]
# [Epoch 57]
# Training - Log Prob: 6.2986
# Validation - Log Prob: 6.0083
# Current learning rates: [0.00025]
# Epoch 58, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 58, validation: 100%|██████████| 4/4 [00:00<00:00, 14.51it/s]
# [Epoch 58]
# Training - Log Prob: 6.4374
# Validation - Log Prob: 6.6246
# Current learning rates: [0.00025]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 59, training: 100%|██████████| 30/30 [00:06<00:00,  4.35it/s]
# Epoch 59, validation: 100%|██████████| 4/4 [00:00<00:00, 13.87it/s]
# [Epoch 59]
# Training - Log Prob: 6.5140
# Validation - Log Prob: 6.3584
# Current learning rates: [0.00025]
# Epoch 60, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 60, validation: 100%|██████████| 4/4 [00:00<00:00,  9.14it/s]
# [Epoch 60]
# Training - Log Prob: 6.2340
# Validation - Log Prob: 6.1517
# Current learning rates: [0.00025]
# Epoch 61, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 61, validation: 100%|██████████| 4/4 [00:00<00:00, 13.47it/s]
# [Epoch 61]
# Training - Log Prob: 6.6226
# Validation - Log Prob: 6.4388
# Current learning rates: [0.00025]
# Epoch 62, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 62, validation: 100%|██████████| 4/4 [00:00<00:00, 13.61it/s]
# [Epoch 62]
# Training - Log Prob: 6.6825
# Validation - Log Prob: 6.6082
# Current learning rates: [0.00025]
# Epoch 63, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 63, validation: 100%|██████████| 4/4 [00:00<00:00, 14.05it/s]
# [Epoch 63]
# Training - Log Prob: 6.2785
# Validation - Log Prob: 6.2512
# Current learning rates: [0.00025]
# Epoch 64, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 64, validation: 100%|██████████| 4/4 [00:00<00:00, 13.70it/s]
# [Epoch 64]
# Training - Log Prob: 6.5934
# Validation - Log Prob: 4.7619
# Current learning rates: [0.00025]
# Epoch 65, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 65, validation: 100%|██████████| 4/4 [00:00<00:00, 13.33it/s]
# [Epoch 65]
# Training - Log Prob: 6.3081
# Validation - Log Prob: 6.3667
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [0.000125]
# Epoch 66, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 66, validation: 100%|██████████| 4/4 [00:00<00:00, 14.15it/s]
# [Epoch 66]
# Training - Log Prob: 6.6690
# Validation - Log Prob: 6.2458
# Current learning rates: [0.000125]
# Epoch 67, training: 100%|██████████| 30/30 [00:07<00:00,  4.07it/s]
# Epoch 67, validation: 100%|██████████| 4/4 [00:00<00:00, 13.56it/s]
# [Epoch 67]
# Training - Log Prob: 6.9725
# Validation - Log Prob: 6.5675
# Current learning rates: [0.000125]
# Epoch 68, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 68, validation: 100%|██████████| 4/4 [00:00<00:00, 13.42it/s]
# [Epoch 68]
# Training - Log Prob: 7.1322
# Validation - Log Prob: 6.6563
# Current learning rates: [0.000125]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 69, training: 100%|██████████| 30/30 [00:07<00:00,  4.09it/s]
# Epoch 69, validation: 100%|██████████| 4/4 [00:00<00:00, 13.70it/s]
# [Epoch 69]
# Training - Log Prob: 7.1857
# Validation - Log Prob: 6.7841
# Current learning rates: [0.000125]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 70, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 70, validation: 100%|██████████| 4/4 [00:00<00:00, 13.66it/s]
# [Epoch 70]
# Training - Log Prob: 7.2516
# Validation - Log Prob: 6.7386
# Current learning rates: [0.000125]
# Epoch 71, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 71, validation: 100%|██████████| 4/4 [00:00<00:00,  8.04it/s]
# [Epoch 71]
# Training - Log Prob: 7.2726
# Validation - Log Prob: 6.8461
# Current learning rates: [0.000125]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 72, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 72, validation: 100%|██████████| 4/4 [00:00<00:00, 13.74it/s]
# [Epoch 72]
# Training - Log Prob: 7.2959
# Validation - Log Prob: 6.7292
# Current learning rates: [0.000125]
# Epoch 73, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 73, validation: 100%|██████████| 4/4 [00:00<00:00, 12.94it/s]
# [Epoch 73]
# Training - Log Prob: 7.3173
# Validation - Log Prob: 6.8225
# Current learning rates: [0.000125]
# Epoch 74, training: 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# Epoch 74, validation: 100%|██████████| 4/4 [00:00<00:00, 13.00it/s]
# [Epoch 74]
# Training - Log Prob: 7.3655
# Validation - Log Prob: 6.7292
# Current learning rates: [0.000125]
# Epoch 75, training: 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# Epoch 75, validation: 100%|██████████| 4/4 [00:00<00:00, 13.26it/s]
# [Epoch 75]
# Training - Log Prob: 7.3678
# Validation - Log Prob: 6.8181
# Current learning rates: [0.000125]
# Epoch 76, training: 100%|██████████| 30/30 [00:07<00:00,  4.06it/s]
# Epoch 76, validation: 100%|██████████| 4/4 [00:00<00:00, 13.21it/s]
# [Epoch 76]
# Training - Log Prob: 7.4002
# Validation - Log Prob: 6.8377
# Current learning rates: [0.000125]
# Epoch 77, training: 100%|██████████| 30/30 [00:07<00:00,  4.06it/s]
# Epoch 77, validation: 100%|██████████| 4/4 [00:00<00:00, 13.50it/s]
# [Epoch 77]
# Training - Log Prob: 7.4283
# Validation - Log Prob: 6.7736
# Current learning rates: [0.000125]
# Epoch 78, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 78, validation: 100%|██████████| 4/4 [00:00<00:00, 13.67it/s]
# [Epoch 78]
# Training - Log Prob: 7.4413
# Validation - Log Prob: 6.8394
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [6.25e-05]
# Epoch 79, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 79, validation: 100%|██████████| 4/4 [00:00<00:00, 13.70it/s]
# [Epoch 79]
# Training - Log Prob: 7.4492
# Validation - Log Prob: 6.9365
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 80, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 80, validation: 100%|██████████| 4/4 [00:00<00:00,  9.08it/s]
# [Epoch 80]
# Training - Log Prob: 7.3618
# Validation - Log Prob: 5.7628
# Current learning rates: [6.25e-05]
# Epoch 81, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 81, validation: 100%|██████████| 4/4 [00:00<00:00, 13.82it/s]
# [Epoch 81]
# Training - Log Prob: 7.3245
# Validation - Log Prob: 6.9460
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 82, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 82, validation: 100%|██████████| 4/4 [00:00<00:00, 13.45it/s]
# [Epoch 82]
# Training - Log Prob: 7.4684
# Validation - Log Prob: 6.9995
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 83, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 83, validation: 100%|██████████| 4/4 [00:00<00:00, 13.34it/s]
# [Epoch 83]
# Training - Log Prob: 7.6234
# Validation - Log Prob: 7.0345
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 84, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 84, validation: 100%|██████████| 4/4 [00:00<00:00, 13.51it/s]
# [Epoch 84]
# Training - Log Prob: 7.6654
# Validation - Log Prob: 7.0607
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 85, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 85, validation: 100%|██████████| 4/4 [00:00<00:00, 13.48it/s]
# [Epoch 85]
# Training - Log Prob: 7.6958
# Validation - Log Prob: 7.0146
# Current learning rates: [6.25e-05]
# Epoch 86, training: 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# Epoch 86, validation: 100%|██████████| 4/4 [00:00<00:00, 13.71it/s]
# [Epoch 86]
# Training - Log Prob: 7.6976
# Validation - Log Prob: 7.0699
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 87, training: 100%|██████████| 30/30 [00:06<00:00,  4.29it/s]
# Epoch 87, validation: 100%|██████████| 4/4 [00:00<00:00, 13.99it/s]
# [Epoch 87]
# Training - Log Prob: 7.7268
# Validation - Log Prob: 7.0670
# Current learning rates: [6.25e-05]
# Epoch 88, training: 100%|██████████| 30/30 [00:06<00:00,  4.34it/s]
# Epoch 88, validation: 100%|██████████| 4/4 [00:00<00:00, 13.75it/s]
# [Epoch 88]
# Training - Log Prob: 7.7471
# Validation - Log Prob: 7.0950
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 89, training: 100%|██████████| 30/30 [00:06<00:00,  4.31it/s]
# Epoch 89, validation: 100%|██████████| 4/4 [00:00<00:00, 14.29it/s]
# [Epoch 89]
# Training - Log Prob: 7.7696
# Validation - Log Prob: 7.1099
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 90, training: 100%|██████████| 30/30 [00:07<00:00,  4.06it/s]
# Epoch 90, validation: 100%|██████████| 4/4 [00:00<00:00, 13.89it/s]
# [Epoch 90]
# Training - Log Prob: 7.7870
# Validation - Log Prob: 7.0279
# Current learning rates: [6.25e-05]
# Epoch 91, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 91, validation: 100%|██████████| 4/4 [00:00<00:00, 13.04it/s]
# [Epoch 91]
# Training - Log Prob: 7.7943
# Validation - Log Prob: 7.0821
# Current learning rates: [6.25e-05]
# Epoch 92, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 92, validation: 100%|██████████| 4/4 [00:00<00:00, 13.90it/s]
# [Epoch 92]
# Training - Log Prob: 7.8051
# Validation - Log Prob: 7.1099
# Current learning rates: [6.25e-05]
# Epoch 93, training: 100%|██████████| 30/30 [00:07<00:00,  4.10it/s]
# Epoch 93, validation: 100%|██████████| 4/4 [00:00<00:00, 12.90it/s]
# [Epoch 93]
# Training - Log Prob: 7.8248
# Validation - Log Prob: 7.1180
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 94, training: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# Epoch 94, validation: 100%|██████████| 4/4 [00:00<00:00, 14.31it/s]
# [Epoch 94]
# Training - Log Prob: 7.8461
# Validation - Log Prob: 7.1502
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 95, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 95, validation: 100%|██████████| 4/4 [00:00<00:00, 14.44it/s]
# [Epoch 95]
# Training - Log Prob: 7.8626
# Validation - Log Prob: 7.0949
# Current learning rates: [6.25e-05]
# Epoch 96, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 96, validation: 100%|██████████| 4/4 [00:00<00:00, 14.03it/s]
# [Epoch 96]
# Training - Log Prob: 7.8746
# Validation - Log Prob: 7.1271
# Current learning rates: [6.25e-05]
# Epoch 97, training: 100%|██████████| 30/30 [00:07<00:00,  4.26it/s]
# Epoch 97, validation: 100%|██████████| 4/4 [00:00<00:00, 13.43it/s]
# [Epoch 97]
# Training - Log Prob: 7.8916
# Validation - Log Prob: 7.1174
# Current learning rates: [6.25e-05]
# Epoch 98, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 98, validation: 100%|██████████| 4/4 [00:00<00:00, 13.94it/s]
# [Epoch 98]
# Training - Log Prob: 7.9044
# Validation - Log Prob: 7.1230
# Current learning rates: [6.25e-05]
# Epoch 99, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 99, validation: 100%|██████████| 4/4 [00:00<00:00, 13.30it/s]
# [Epoch 99]
# Training - Log Prob: 7.9106
# Validation - Log Prob: 7.1200
# Current learning rates: [6.25e-05]
# Epoch 100, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 100, validation: 100%|██████████| 4/4 [00:00<00:00, 13.83it/s]
# [Epoch 100]
# Training - Log Prob: 7.9283
# Validation - Log Prob: 7.1050
# Current learning rates: [6.25e-05]
# Epoch 101, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 101, validation: 100%|██████████| 4/4 [00:00<00:00, 13.30it/s]
# [Epoch 101]
# Training - Log Prob: 7.9405
# Validation - Log Prob: 7.1639
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 102, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 102, validation: 100%|██████████| 4/4 [00:00<00:00, 13.70it/s]
# [Epoch 102]
# Training - Log Prob: 7.9536
# Validation - Log Prob: 7.1248
# Current learning rates: [6.25e-05]
# Epoch 103, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 103, validation: 100%|██████████| 4/4 [00:00<00:00, 14.39it/s]
# [Epoch 103]
# Training - Log Prob: 7.9648
# Validation - Log Prob: 7.1627
# Current learning rates: [6.25e-05]
# Epoch 104, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 104, validation: 100%|██████████| 4/4 [00:00<00:00, 13.58it/s]
# [Epoch 104]
# Training - Log Prob: 7.9893
# Validation - Log Prob: 7.1365
# Current learning rates: [6.25e-05]
# Epoch 105, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 105, validation: 100%|██████████| 4/4 [00:00<00:00, 14.89it/s]
# [Epoch 105]
# Training - Log Prob: 7.9924
# Validation - Log Prob: 7.1706
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 106, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 106, validation: 100%|██████████| 4/4 [00:00<00:00, 13.43it/s]
# [Epoch 106]
# Training - Log Prob: 8.0120
# Validation - Log Prob: 7.1190
# Current learning rates: [6.25e-05]
# Epoch 107, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 107, validation: 100%|██████████| 4/4 [00:00<00:00, 13.92it/s]
# [Epoch 107]
# Training - Log Prob: 8.0075
# Validation - Log Prob: 7.1762
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 108, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 108, validation: 100%|██████████| 4/4 [00:00<00:00, 14.11it/s]
# [Epoch 108]
# Training - Log Prob: 8.0289
# Validation - Log Prob: 7.1293
# Current learning rates: [6.25e-05]
# Epoch 109, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 109, validation: 100%|██████████| 4/4 [00:00<00:00, 13.24it/s]
# [Epoch 109]
# Training - Log Prob: 8.0436
# Validation - Log Prob: 7.1767
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 110, training: 100%|██████████| 30/30 [00:06<00:00,  4.33it/s]
# Epoch 110, validation: 100%|██████████| 4/4 [00:00<00:00, 14.15it/s]
# [Epoch 110]
# Training - Log Prob: 8.0585
# Validation - Log Prob: 7.1654
# Current learning rates: [6.25e-05]
# Epoch 111, training: 100%|██████████| 30/30 [00:06<00:00,  4.33it/s]
# Epoch 111, validation: 100%|██████████| 4/4 [00:00<00:00, 14.35it/s]
# [Epoch 111]
# Training - Log Prob: 8.0681
# Validation - Log Prob: 7.1559
# Current learning rates: [6.25e-05]
# Epoch 112, training: 100%|██████████| 30/30 [00:06<00:00,  4.33it/s]
# Epoch 112, validation: 100%|██████████| 4/4 [00:00<00:00,  9.10it/s]
# [Epoch 112]
# Training - Log Prob: 8.0453
# Validation - Log Prob: 7.2084
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 113, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 113, validation: 100%|██████████| 4/4 [00:00<00:00, 13.25it/s]
# [Epoch 113]
# Training - Log Prob: 8.0041
# Validation - Log Prob: 7.1651
# Current learning rates: [6.25e-05]
# Epoch 114, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 114, validation: 100%|██████████| 4/4 [00:00<00:00, 13.86it/s]
# [Epoch 114]
# Training - Log Prob: 8.0968
# Validation - Log Prob: 7.2356
# Current learning rates: [6.25e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 115, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 115, validation: 100%|██████████| 4/4 [00:00<00:00, 14.04it/s]
# [Epoch 115]
# Training - Log Prob: 8.1021
# Validation - Log Prob: 7.1103
# Current learning rates: [6.25e-05]
# Epoch 116, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 116, validation: 100%|██████████| 4/4 [00:00<00:00, 14.27it/s]
# [Epoch 116]
# Training - Log Prob: 7.9883
# Validation - Log Prob: 7.0853
# Current learning rates: [6.25e-05]
# Epoch 117, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 117, validation: 100%|██████████| 4/4 [00:00<00:00, 14.19it/s]
# [Epoch 117]
# Training - Log Prob: 8.0922
# Validation - Log Prob: 7.2226
# Current learning rates: [6.25e-05]
# Epoch 118, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 118, validation: 100%|██████████| 4/4 [00:00<00:00,  9.08it/s]
# [Epoch 118]
# Training - Log Prob: 8.1305
# Validation - Log Prob: 7.2305
# Current learning rates: [6.25e-05]
# Epoch 119, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 119, validation: 100%|██████████| 4/4 [00:00<00:00, 13.13it/s]
# [Epoch 119]
# Training - Log Prob: 7.9875
# Validation - Log Prob: 6.8042
# Current learning rates: [6.25e-05]
# Epoch 120, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 120, validation: 100%|██████████| 4/4 [00:00<00:00, 13.45it/s]
# [Epoch 120]
# Training - Log Prob: 8.0519
# Validation - Log Prob: 7.2125
# Current learning rates: [6.25e-05]
# Epoch 121, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 121, validation: 100%|██████████| 4/4 [00:00<00:00, 13.44it/s]
# [Epoch 121]
# Training - Log Prob: 8.0428
# Validation - Log Prob: 7.2149
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [3.125e-05]
# Epoch 122, training: 100%|██████████| 30/30 [00:06<00:00,  4.30it/s]
# Epoch 122, validation: 100%|██████████| 4/4 [00:00<00:00,  9.63it/s]
# [Epoch 122]
# Training - Log Prob: 8.1284
# Validation - Log Prob: 7.1438
# Current learning rates: [3.125e-05]
# Epoch 123, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 123, validation: 100%|██████████| 4/4 [00:00<00:00, 13.38it/s]
# [Epoch 123]
# Training - Log Prob: 8.1718
# Validation - Log Prob: 7.2232
# Current learning rates: [3.125e-05]
# Epoch 124, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 124, validation: 100%|██████████| 4/4 [00:00<00:00, 13.58it/s]
# [Epoch 124]
# Training - Log Prob: 8.2183
# Validation - Log Prob: 7.3254
# Current learning rates: [3.125e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 125, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 125, validation: 100%|██████████| 4/4 [00:00<00:00, 13.95it/s]
# [Epoch 125]
# Training - Log Prob: 8.2279
# Validation - Log Prob: 7.2793
# Current learning rates: [3.125e-05]
# Epoch 126, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 126, validation: 100%|██████████| 4/4 [00:00<00:00, 14.09it/s]
# [Epoch 126]
# Training - Log Prob: 8.2337
# Validation - Log Prob: 7.2259
# Current learning rates: [3.125e-05]
# Epoch 127, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 127, validation: 100%|██████████| 4/4 [00:00<00:00,  9.01it/s]
# [Epoch 127]
# Training - Log Prob: 8.2653
# Validation - Log Prob: 7.2864
# Current learning rates: [3.125e-05]
# Epoch 128, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 128, validation: 100%|██████████| 4/4 [00:00<00:00, 13.71it/s]
# [Epoch 128]
# Training - Log Prob: 8.2509
# Validation - Log Prob: 7.2434
# Current learning rates: [3.125e-05]
# Epoch 129, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 129, validation: 100%|██████████| 4/4 [00:00<00:00, 13.83it/s]
# [Epoch 129]
# Training - Log Prob: 8.2309
# Validation - Log Prob: 7.2478
# Current learning rates: [3.125e-05]
# Epoch 130, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 130, validation: 100%|██████████| 4/4 [00:00<00:00, 14.01it/s]
# [Epoch 130]
# Training - Log Prob: 8.2923
# Validation - Log Prob: 7.2809
# Current learning rates: [3.125e-05]
# Epoch 131, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 131, validation: 100%|██████████| 4/4 [00:00<00:00, 13.61it/s]
# [Epoch 131]
# Training - Log Prob: 8.3231
# Validation - Log Prob: 7.3088
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [1.5625e-05]
# Epoch 132, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 132, validation: 100%|██████████| 4/4 [00:00<00:00,  9.45it/s]
# [Epoch 132]
# Training - Log Prob: 8.2770
# Validation - Log Prob: 7.3173
# Current learning rates: [1.5625e-05]
# Epoch 133, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 133, validation: 100%|██████████| 4/4 [00:00<00:00, 14.35it/s]
# [Epoch 133]
# Training - Log Prob: 8.2908
# Validation - Log Prob: 7.3173
# Current learning rates: [1.5625e-05]
# Epoch 134, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 134, validation: 100%|██████████| 4/4 [00:00<00:00, 13.80it/s]
# [Epoch 134]
# Training - Log Prob: 8.3030
# Validation - Log Prob: 7.3022
# Current learning rates: [1.5625e-05]
# Epoch 135, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 135, validation: 100%|██████████| 4/4 [00:00<00:00, 13.19it/s]
# [Epoch 135]
# Training - Log Prob: 8.3145
# Validation - Log Prob: 7.2455
# Current learning rates: [1.5625e-05]
# Epoch 136, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 136, validation: 100%|██████████| 4/4 [00:00<00:00, 13.94it/s]
# [Epoch 136]
# Training - Log Prob: 8.3322
# Validation - Log Prob: 7.2934
# Current learning rates: [1.5625e-05]
# Epoch 137, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 137, validation: 100%|██████████| 4/4 [00:00<00:00, 13.72it/s]
# [Epoch 137]
# Training - Log Prob: 8.3310
# Validation - Log Prob: 7.2822
# Current learning rates: [1.5625e-05]
# Epoch 138, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 138, validation: 100%|██████████| 4/4 [00:00<00:00, 13.48it/s]
# [Epoch 138]
# Training - Log Prob: 8.3488
# Validation - Log Prob: 7.3450
# Current learning rates: [1.5625e-05]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 139, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 139, validation: 100%|██████████| 4/4 [00:00<00:00, 14.27it/s]
# [Epoch 139]
# Training - Log Prob: 8.3417
# Validation - Log Prob: 7.2816
# Current learning rates: [1.5625e-05]
# Epoch 140, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 140, validation: 100%|██████████| 4/4 [00:00<00:00, 13.95it/s]
# [Epoch 140]
# Training - Log Prob: 8.3398
# Validation - Log Prob: 7.3052
# Current learning rates: [1.5625e-05]
# Epoch 141, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 141, validation: 100%|██████████| 4/4 [00:00<00:00, 13.90it/s]
# [Epoch 141]
# Training - Log Prob: 8.3654
# Validation - Log Prob: 7.3014
# Current learning rates: [1.5625e-05]
# Epoch 142, training: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 142, validation: 100%|██████████| 4/4 [00:00<00:00, 13.80it/s]
# [Epoch 142]
# Training - Log Prob: 8.3588
# Validation - Log Prob: 7.3272
# Current learning rates: [1.5625e-05]
# Epoch 143, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 143, validation: 100%|██████████| 4/4 [00:00<00:00, 13.84it/s]
# [Epoch 143]
# Training - Log Prob: 8.3844
# Validation - Log Prob: 7.3114
# Current learning rates: [1.5625e-05]
# Epoch 144, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 144, validation: 100%|██████████| 4/4 [00:00<00:00, 13.71it/s]
# [Epoch 144]
# Training - Log Prob: 8.3914
# Validation - Log Prob: 7.3272
# Current learning rates: [1.5625e-05]
# Epoch 145, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 145, validation: 100%|██████████| 4/4 [00:00<00:00, 13.67it/s]
# [Epoch 145]
# Training - Log Prob: 8.4254
# Validation - Log Prob: 7.3448
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [7.8125e-06]
# Epoch 146, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 146, validation: 100%|██████████| 4/4 [00:00<00:00, 13.54it/s]
# [Epoch 146]
# Training - Log Prob: 8.3778
# Validation - Log Prob: 7.3598
# Current learning rates: [7.8125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 147, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 147, validation: 100%|██████████| 4/4 [00:00<00:00,  9.43it/s]
# [Epoch 147]
# Training - Log Prob: 8.3793
# Validation - Log Prob: 7.3362
# Current learning rates: [7.8125e-06]
# Epoch 148, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 148, validation: 100%|██████████| 4/4 [00:00<00:00, 13.49it/s]
# [Epoch 148]
# Training - Log Prob: 8.3985
# Validation - Log Prob: 7.3479
# Current learning rates: [7.8125e-06]
# Epoch 149, training: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# Epoch 149, validation: 100%|██████████| 4/4 [00:00<00:00, 13.02it/s]
# [Epoch 149]
# Training - Log Prob: 8.4032
# Validation - Log Prob: 7.3540
# Current learning rates: [7.8125e-06]
# Epoch 150, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 150, validation: 100%|██████████| 4/4 [00:00<00:00, 14.03it/s]
# [Epoch 150]
# Training - Log Prob: 8.4062
# Validation - Log Prob: 7.3356
# Current learning rates: [7.8125e-06]
# Epoch 151, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 151, validation: 100%|██████████| 4/4 [00:00<00:00, 13.87it/s]
# [Epoch 151]
# Training - Log Prob: 8.4148
# Validation - Log Prob: 7.3559
# Current learning rates: [7.8125e-06]
# Epoch 152, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 152, validation: 100%|██████████| 4/4 [00:00<00:00, 13.33it/s]
# [Epoch 152]
# Training - Log Prob: 8.4192
# Validation - Log Prob: 7.3615
# Current learning rates: [7.8125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 153, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 153, validation: 100%|██████████| 4/4 [00:00<00:00, 13.37it/s]
# [Epoch 153]
# Training - Log Prob: 8.4273
# Validation - Log Prob: 7.3480
# Current learning rates: [7.8125e-06]
# Epoch 154, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 154, validation: 100%|██████████| 4/4 [00:00<00:00, 13.97it/s]
# [Epoch 154]
# Training - Log Prob: 8.4308
# Validation - Log Prob: 7.3510
# Current learning rates: [7.8125e-06]
# Epoch 155, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 155, validation: 100%|██████████| 4/4 [00:00<00:00, 13.78it/s]
# [Epoch 155]
# Training - Log Prob: 8.4364
# Validation - Log Prob: 7.3640
# Current learning rates: [7.8125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 156, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 156, validation: 100%|██████████| 4/4 [00:00<00:00,  9.28it/s]
# [Epoch 156]
# Training - Log Prob: 8.4533
# Validation - Log Prob: 7.3523
# Current learning rates: [7.8125e-06]
# Epoch 157, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 157, validation: 100%|██████████| 4/4 [00:00<00:00, 14.28it/s]
# [Epoch 157]
# Training - Log Prob: 8.4536
# Validation - Log Prob: 7.3656
# Current learning rates: [7.8125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 158, training: 100%|██████████| 30/30 [00:06<00:00,  4.29it/s]
# Epoch 158, validation: 100%|██████████| 4/4 [00:00<00:00, 13.57it/s]
# [Epoch 158]
# Training - Log Prob: 8.4592
# Validation - Log Prob: 7.3435
# Current learning rates: [7.8125e-06]
# Epoch 159, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 159, validation: 100%|██████████| 4/4 [00:00<00:00, 13.90it/s]
# [Epoch 159]
# Training - Log Prob: 8.4628
# Validation - Log Prob: 7.3578
# Current learning rates: [7.8125e-06]
# Epoch 160, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 160, validation: 100%|██████████| 4/4 [00:00<00:00, 13.98it/s]
# [Epoch 160]
# Training - Log Prob: 8.4649
# Validation - Log Prob: 7.3503
# Current learning rates: [7.8125e-06]
# Epoch 161, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 161, validation: 100%|██████████| 4/4 [00:00<00:00, 13.83it/s]
# [Epoch 161]
# Training - Log Prob: 8.4712
# Validation - Log Prob: 7.3610
# Current learning rates: [7.8125e-06]
# Epoch 162, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 162, validation: 100%|██████████| 4/4 [00:00<00:00, 13.97it/s]
# [Epoch 162]
# Training - Log Prob: 8.4793
# Validation - Log Prob: 7.3491
# Current learning rates: [7.8125e-06]
# Epoch 163, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 163, validation: 100%|██████████| 4/4 [00:00<00:00, 13.85it/s]
# [Epoch 163]
# Training - Log Prob: 8.4863
# Validation - Log Prob: 7.3718
# Current learning rates: [7.8125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 164, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 164, validation: 100%|██████████| 4/4 [00:00<00:00,  9.19it/s]
# [Epoch 164]
# Training - Log Prob: 8.4874
# Validation - Log Prob: 7.3484
# Current learning rates: [7.8125e-06]
# Epoch 165, training: 100%|██████████| 30/30 [00:06<00:00,  4.36it/s]
# Epoch 165, validation: 100%|██████████| 4/4 [00:00<00:00, 13.83it/s]
# [Epoch 165]
# Training - Log Prob: 8.4933
# Validation - Log Prob: 7.3619
# Current learning rates: [7.8125e-06]
# Epoch 166, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 166, validation: 100%|██████████| 4/4 [00:00<00:00, 14.12it/s]
# [Epoch 166]
# Training - Log Prob: 8.4951
# Validation - Log Prob: 7.3562
# Current learning rates: [7.8125e-06]
# Epoch 167, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 167, validation: 100%|██████████| 4/4 [00:00<00:00, 13.36it/s]
# [Epoch 167]
# Training - Log Prob: 8.4984
# Validation - Log Prob: 7.3544
# Current learning rates: [7.8125e-06]
# Epoch 168, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 168, validation: 100%|██████████| 4/4 [00:00<00:00, 13.56it/s]
# [Epoch 168]
# Training - Log Prob: 8.5044
# Validation - Log Prob: 7.3497
# Current learning rates: [7.8125e-06]
# Epoch 169, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 169, validation: 100%|██████████| 4/4 [00:00<00:00, 14.29it/s]
# [Epoch 169]
# Training - Log Prob: 8.5060
# Validation - Log Prob: 7.3602
# Current learning rates: [7.8125e-06]
# Epoch 170, training: 100%|██████████| 30/30 [00:07<00:00,  4.12it/s]
# Epoch 170, validation: 100%|██████████| 4/4 [00:00<00:00,  8.87it/s]
# [Epoch 170]
# Training - Log Prob: 8.5156
# Validation - Log Prob: 7.3650
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [3.90625e-06]
# Epoch 171, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 171, validation: 100%|██████████| 4/4 [00:00<00:00, 13.58it/s]
# [Epoch 171]
# Training - Log Prob: 8.5022
# Validation - Log Prob: 7.3707
# Current learning rates: [3.90625e-06]
# Epoch 172, training: 100%|██████████| 30/30 [00:07<00:00,  4.07it/s]
# Epoch 172, validation: 100%|██████████| 4/4 [00:00<00:00, 14.14it/s]
# [Epoch 172]
# Training - Log Prob: 8.5015
# Validation - Log Prob: 7.3697
# Current learning rates: [3.90625e-06]
# Epoch 173, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 173, validation: 100%|██████████| 4/4 [00:00<00:00, 13.85it/s]
# [Epoch 173]
# Training - Log Prob: 8.5073
# Validation - Log Prob: 7.3707
# Current learning rates: [3.90625e-06]
# Epoch 174, training: 100%|██████████| 30/30 [00:07<00:00,  4.09it/s]
# Epoch 174, validation: 100%|██████████| 4/4 [00:00<00:00, 13.49it/s]
# [Epoch 174]
# Training - Log Prob: 8.5101
# Validation - Log Prob: 7.3696
# Current learning rates: [3.90625e-06]
# Epoch 175, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 175, validation: 100%|██████████| 4/4 [00:00<00:00, 13.61it/s]
# [Epoch 175]
# Training - Log Prob: 8.5167
# Validation - Log Prob: 7.3654
# Current learning rates: [3.90625e-06]
# Epoch 176, training: 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# Epoch 176, validation: 100%|██████████| 4/4 [00:00<00:00, 13.47it/s]
# [Epoch 176]
# Training - Log Prob: 8.5186
# Validation - Log Prob: 7.3688
# Current learning rates: [3.90625e-06]
# Epoch 177, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 177, validation: 100%|██████████| 4/4 [00:00<00:00, 13.96it/s]
# [Epoch 177]
# Training - Log Prob: 8.5236
# Validation - Log Prob: 7.3665
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [1.953125e-06]
# Epoch 178, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 178, validation: 100%|██████████| 4/4 [00:00<00:00,  9.40it/s]
# [Epoch 178]
# Training - Log Prob: 8.5085
# Validation - Log Prob: 7.3745
# Current learning rates: [1.953125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 179, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 179, validation: 100%|██████████| 4/4 [00:00<00:00, 14.33it/s]
# [Epoch 179]
# Training - Log Prob: 8.5134
# Validation - Log Prob: 7.3739
# Current learning rates: [1.953125e-06]
# Epoch 180, training: 100%|██████████| 30/30 [00:06<00:00,  4.31it/s]
# Epoch 180, validation: 100%|██████████| 4/4 [00:00<00:00, 13.30it/s]
# [Epoch 180]
# Training - Log Prob: 8.5136
# Validation - Log Prob: 7.3730
# Current learning rates: [1.953125e-06]
# Epoch 181, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 181, validation: 100%|██████████| 4/4 [00:00<00:00, 13.83it/s]
# [Epoch 181]
# Training - Log Prob: 8.5159
# Validation - Log Prob: 7.3708
# Current learning rates: [1.953125e-06]
# Epoch 182, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 182, validation: 100%|██████████| 4/4 [00:00<00:00, 13.39it/s]
# [Epoch 182]
# Training - Log Prob: 8.5150
# Validation - Log Prob: 7.3753
# Current learning rates: [1.953125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 183, training: 100%|██████████| 30/30 [00:07<00:00,  4.27it/s]
# Epoch 183, validation: 100%|██████████| 4/4 [00:00<00:00, 13.36it/s]
# [Epoch 183]
# Training - Log Prob: 8.5206
# Validation - Log Prob: 7.3741
# Current learning rates: [1.953125e-06]
# Epoch 184, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 184, validation: 100%|██████████| 4/4 [00:00<00:00, 14.22it/s]
# [Epoch 184]
# Training - Log Prob: 8.5225
# Validation - Log Prob: 7.3709
# Current learning rates: [1.953125e-06]
# Epoch 185, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 185, validation: 100%|██████████| 4/4 [00:00<00:00, 14.11it/s]
# [Epoch 185]
# Training - Log Prob: 8.5256
# Validation - Log Prob: 7.3729
# Current learning rates: [1.953125e-06]
# Epoch 186, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 186, validation: 100%|██████████| 4/4 [00:00<00:00, 13.60it/s]
# [Epoch 186]
# Training - Log Prob: 8.5258
# Validation - Log Prob: 7.3749
# Current learning rates: [1.953125e-06]
# Epoch 187, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 187, validation: 100%|██████████| 4/4 [00:00<00:00, 13.42it/s]
# [Epoch 187]
# Training - Log Prob: 8.5282
# Validation - Log Prob: 7.3768
# Current learning rates: [1.953125e-06]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 188, training: 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# Epoch 188, validation: 100%|██████████| 4/4 [00:00<00:00, 13.74it/s]
# [Epoch 188]
# Training - Log Prob: 8.5287
# Validation - Log Prob: 7.3720
# Current learning rates: [1.953125e-06]
# Epoch 189, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 189, validation: 100%|██████████| 4/4 [00:00<00:00, 14.08it/s]
# [Epoch 189]
# Training - Log Prob: 8.5318
# Validation - Log Prob: 7.3729
# Current learning rates: [1.953125e-06]
# Epoch 190, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 190, validation: 100%|██████████| 4/4 [00:00<00:00,  9.17it/s]
# [Epoch 190]
# Training - Log Prob: 8.5327
# Validation - Log Prob: 7.3749
# Current learning rates: [1.953125e-06]
# Epoch 191, training: 100%|██████████| 30/30 [00:06<00:00,  4.35it/s]
# Epoch 191, validation: 100%|██████████| 4/4 [00:00<00:00,  8.82it/s]
# [Epoch 191]
# Training - Log Prob: 8.5350
# Validation - Log Prob: 7.3724
# Current learning rates: [1.953125e-06]
# Epoch 192, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 192, validation: 100%|██████████| 4/4 [00:00<00:00, 14.65it/s]
# [Epoch 192]
# Training - Log Prob: 8.5341
# Validation - Log Prob: 7.3749
# Current learning rates: [1.953125e-06]
# Epoch 193, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 193, validation: 100%|██████████| 4/4 [00:00<00:00, 14.20it/s]
# [Epoch 193]
# Training - Log Prob: 8.5359
# Validation - Log Prob: 7.3708
# Current learning rates: [1.953125e-06]
# Epoch 194, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 194, validation: 100%|██████████| 4/4 [00:00<00:00, 14.15it/s]
# [Epoch 194]
# Training - Log Prob: 8.5410
# Validation - Log Prob: 7.3728
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [9.765625e-07]
# Epoch 195, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 195, validation: 100%|██████████| 4/4 [00:00<00:00, 13.56it/s]
# [Epoch 195]
# Training - Log Prob: 8.5337
# Validation - Log Prob: 7.3762
# Current learning rates: [9.765625e-07]
# Epoch 196, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 196, validation: 100%|██████████| 4/4 [00:00<00:00, 14.17it/s]
# [Epoch 196]
# Training - Log Prob: 8.5340
# Validation - Log Prob: 7.3771
# Current learning rates: [9.765625e-07]
# New best validation performance
#
# Model checkpoint saved to Dingo.pt
# Epoch 197, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 197, validation: 100%|██████████| 4/4 [00:00<00:00, 13.70it/s]
# [Epoch 197]
# Training - Log Prob: 8.5367
# Validation - Log Prob: 7.3746
# Current learning rates: [9.765625e-07]
# Epoch 198, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 198, validation: 100%|██████████| 4/4 [00:00<00:00, 13.71it/s]
# [Epoch 198]
# Training - Log Prob: 8.5365
# Validation - Log Prob: 7.3750
# Current learning rates: [9.765625e-07]
# Epoch 199, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 199, validation: 100%|██████████| 4/4 [00:00<00:00, 13.05it/s]
# [Epoch 199]
# Training - Log Prob: 8.5374
# Validation - Log Prob: 7.3758
# Current learning rates: [9.765625e-07]
# Epoch 200, training: 100%|██████████| 30/30 [00:07<00:00,  4.03it/s]
# Epoch 200, validation: 100%|██████████| 4/4 [00:00<00:00, 14.05it/s]
# [Epoch 200]
# Training - Log Prob: 8.5406
# Validation - Log Prob: 7.3741
# Current learning rates: [9.765625e-07]
# Epoch 201, training: 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# Epoch 201, validation: 100%|██████████| 4/4 [00:00<00:00, 13.93it/s]
# [Epoch 201]
# Training - Log Prob: 8.5385
# Validation - Log Prob: 7.3758
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [4.8828125e-07]
# Epoch 202, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 202, validation: 100%|██████████| 4/4 [00:00<00:00, 13.72it/s]
# [Epoch 202]
# Training - Log Prob: 8.5380
# Validation - Log Prob: 7.3767
# Current learning rates: [4.8828125e-07]
# Epoch 203, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 203, validation: 100%|██████████| 4/4 [00:00<00:00, 13.51it/s]
# [Epoch 203]
# Training - Log Prob: 8.5424
# Validation - Log Prob: 7.3764
# Current learning rates: [4.8828125e-07]
# Epoch 204, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 204, validation: 100%|██████████| 4/4 [00:00<00:00, 13.86it/s]
# [Epoch 204]
# Training - Log Prob: 8.5381
# Validation - Log Prob: 7.3761
# Current learning rates: [4.8828125e-07]
# Epoch 205, training: 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# Epoch 205, validation: 100%|██████████| 4/4 [00:00<00:00, 13.53it/s]
# [Epoch 205]
# Training - Log Prob: 8.5403
# Validation - Log Prob: 7.3758
# Current learning rates: [4.8828125e-07]
# Epoch 206, training: 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# Epoch 206, validation: 100%|██████████| 4/4 [00:00<00:00, 13.01it/s]
# [Epoch 206]
# Training - Log Prob: 8.5420
# Validation - Log Prob: 7.3759
# Current learning rates: [4.8828125e-07]
# Epoch 207, training: 100%|██████████| 30/30 [00:07<00:00,  4.11it/s]
# Epoch 207, validation: 100%|██████████| 4/4 [00:00<00:00, 13.03it/s]
# [Epoch 207]
# Training - Log Prob: 8.5401
# Validation - Log Prob: 7.3766
# Current learning rates: [4.8828125e-07]
# Epoch 208, training: 100%|██████████| 30/30 [00:07<00:00,  4.14it/s]
# Epoch 208, validation: 100%|██████████| 4/4 [00:00<00:00, 13.91it/s]
# [Epoch 208]
# Training - Log Prob: 8.5408
# Validation - Log Prob: 7.3766
# Learning rate reduced. Loading best model from Dingo.pt
# Best model loaded, resuming training
#
# Current learning rates: [2.44140625e-07]
# Epoch 209, training: 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# Epoch 209, validation: 100%|██████████| 4/4 [00:00<00:00, 13.90it/s]
# [Epoch 209]
# Training - Log Prob: 8.5398
# Validation - Log Prob: 7.3764
# Current learning rates: [2.44140625e-07]
# Epoch 210, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 210, validation: 100%|██████████| 4/4 [00:00<00:00, 13.51it/s]
# [Epoch 210]
# Training - Log Prob: 8.5397
# Validation - Log Prob: 7.3767
# Current learning rates: [2.44140625e-07]
# Epoch 211, training: 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# Epoch 211, validation: 100%|██████████| 4/4 [00:00<00:00, 12.96it/s]
# [Epoch 211]
# Training - Log Prob: 8.5400
# Validation - Log Prob: 7.3770
# Current learning rates: [2.44140625e-07]
# Epoch 212, training: 100%|██████████| 30/30 [00:07<00:00,  4.15it/s]
# Epoch 212, validation: 100%|██████████| 4/4 [00:00<00:00, 13.86it/s]
# [Epoch 212]
# Training - Log Prob: 8.5394
# Validation - Log Prob: 7.3764
# Current learning rates: [2.44140625e-07]
# Epoch 213, training: 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# Epoch 213, validation: 100%|██████████| 4/4 [00:00<00:00, 13.62it/s]
# [Epoch 213]
# Training - Log Prob: 8.5402
# Validation - Log Prob: 7.3771
# Current learning rates: [2.44140625e-07]
# Epoch 214, training: 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# Epoch 214, validation: 100%|██████████| 4/4 [00:00<00:00, 12.85it/s]
# [Epoch 214]
# Training - Log Prob: 8.5438
# Validation - Log Prob: 7.3767
# Current learning rates: [2.44140625e-07]
# No improvement in validation log prob in last 18 epochs

# %%
plt.figure(figsize=(10, 5))
plt.plot(training_stuff['train_log_probs'], linewidth=2, label='Train Log Probability')
plt.plot(training_stuff['val_log_probs'], linewidth=2, label='Validation Log Probability')
plt.legend(fontsize=12)
plt.title('NPE Model Training Progress: Log Probability', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Log Probability')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Taken from old stuff and updated w claude and myself
from matplotlib.patches import Rectangle # Rectangle where both axes' 1-sigma regions overlap

model, _ = load_npe("Dingo.pt")

# Test on several different true frequencies, phases, and amplitudes
test_frequencies = [1.0, 2.5, 4.0]
test_phases = [0.5, -0.3, 1.2]
test_amplitudes = [1.0, 0.8, 2.4]

fig, axes = plt.subplots(7, len(test_frequencies), figsize=(8*len(test_frequencies), 40))

print("Testing NPE model on new observations:\n")

for idx, true_freq in enumerate(test_frequencies):
    true_phase = test_phases[idx]
    true_amp = test_amplitudes[idx]
    print(f"\nTest {idx+1}: True Frequency = {true_freq}, True Phase = {true_phase:.2f}, True Amplitude = {true_amp:.2f}")
    
    # Generate new observation
    observed_data = simulate_sine_wave(true_freq, phase=true_phase, amplitude=true_amp)
    
    # Infer posterior
    posterior_samples, stats = infer_NPE(model, observed_data, num_samples=5000)
    
    # Handle both 1D and 2D cases for posterior samples
    if len(posterior_samples.shape) == 1:
        # 1D case - shouldn't happen with 3 params
        amp_samples = posterior_samples
        freq_samples = posterior_samples
        phase_samples = posterior_samples
    else:
        # 2D case [num_samples, 3] with [amplitude, frequency, phase]
        amp_samples = posterior_samples[:, 0]
        freq_samples = posterior_samples[:, 1]
        phase_samples = posterior_samples[:, 2]
    
    freq_stats = {
        'mean': np.mean(freq_samples),
        'median': np.median(freq_samples),
        'std': np.std(freq_samples),
        'q05': np.percentile(freq_samples, 5),
        'q95': np.percentile(freq_samples, 95),
    }
    
    phase_stats = {
        'mean': np.mean(phase_samples),
        'median': np.median(phase_samples),
        'std': np.std(phase_samples),
        'q05': np.percentile(phase_samples, 5),
        'q95': np.percentile(phase_samples, 95),
    }
    
    amp_stats = {
        'mean': np.mean(amp_samples),
        'median': np.median(amp_samples),
        'std': np.std(amp_samples),
        'q05': np.percentile(amp_samples, 5),
        'q95': np.percentile(amp_samples, 95),
    }
    
    parameters = ['amplitude', 'frequency', 'phase']
    ps = ['A', 'f', 'φ']
    samples_list = [amp_samples, freq_samples, phase_samples]
    stats_list = [amp_stats, freq_stats, phase_stats]
    true_list = [true_amp, true_freq, true_phase]

    print(f"  Frequency posterior: mean={freq_stats['mean']:.3f} ± {freq_stats['std']:.3f}")
    print(f"  Phase posterior:     mean={phase_stats['mean']:.3f} ± {phase_stats['std']:.3f}")
    print(f"  Amplitude posterior: mean={amp_stats['mean']:.3f} ± {amp_stats['std']:.3f}")
    
    t = np.linspace(0, 6*np.pi, 1000)

    # Plot observed data
    axes[0, idx].plot(t, observed_data, 'b-', alpha=0.7, linewidth=1.5, label='Observed')
    axes[0, idx].plot(t, true_amp * np.sin(2*np.pi*true_freq * t + true_phase), 'r--', 
                      label=f'True (f={true_freq}, φ={true_phase:.2f}, A={true_amp:.2f})', linewidth=2)
    axes[0, idx].set_title(f'Test {idx+1}: f={true_freq}, φ={true_phase:.2f}, A={true_amp:.2f}', fontsize=12, fontweight='bold')
    axes[0, idx].set_xlabel('Time')
    axes[0, idx].set_ylabel('Value')
    axes[0, idx].legend(fontsize=8)
    axes[0, idx].grid(True, alpha=0.3)

    for idx2, _ in enumerate(parameters):
        axes[idx2 + 1, idx].hist(samples_list[idx2], bins=60, density=True, 
                      alpha=0.6, edgecolor='black', label='Posterior')
        axes[idx2 + 1, idx].axvline(true_list[idx2], color='red', linestyle='--', 
                             linewidth=2.5, label=f'True: {true_list[idx2]:.2f}', zorder=10)
        axes[idx2 + 1, idx].axvline(stats_list[idx2]['mean'], color='green', linestyle='-', 
                             linewidth=2.5, label=f"Mean: {stats_list[idx2]['mean']:.2f}", zorder=10)
        axes[idx2 + 1, idx].axvspan(stats_list[idx2]['q05'], stats_list[idx2]['q95'], alpha=0.2, color='gray', label='90% CI')
        axes[idx2 + 1, idx].set_title(f'p({parameters[idx2]} | data)', fontsize=12, fontweight='bold')
        axes[idx2 + 1, idx].set_xlabel(parameters[idx2].capitalize())
        axes[idx2 + 1, idx].set_ylabel('Density')
        axes[idx2 + 1, idx].legend(loc='upper right', fontsize=8)
        axes[idx2 + 1, idx].grid(True, alpha=0.3)

    for idx2, _ in enumerate(parameters):
        # 2D histograms for parameter pairs
        h = axes[len(parameters) + idx2 + 1, idx].hist2d(samples_list[idx2], samples_list[(idx2+1) % 3], bins=60, cmap='plasma', density=True)
        plt.colorbar(h[3], ax=axes[len(parameters) + idx2 + 1, idx], label='Probability Density')
        axes[len(parameters) + idx2 + 1, idx].scatter(true_list[idx2], true_list[(idx2+1) % 3], color='cyan', s=200, marker='x',  
                            edgecolors='white', linewidth=2, label='True values', zorder=10) # Plot true values
        axes[len(parameters) + idx2 + 1, idx].scatter(stats_list[idx2]['mean'], stats_list[(idx2+1) % 3]['mean'], color='lime', s=100, marker='o', 
                            linewidth=3, label='Posterior mean', zorder=10) # Plot mean

        rect = Rectangle((stats_list[idx2]['mean'] - stats_list[idx2]['std'], stats_list[(idx2+1) % 3]['mean'] - stats_list[(idx2+1) % 3]['std']), 
                        width=2*stats_list[idx2]['std'], height=2*stats_list[(idx2+1) % 3]['std'],
                        facecolor='yellow', edgecolor='yellow', linewidth=2, 
                        alpha=0.3, label='1σ region', zorder=5)
        
        axes[len(parameters) + idx2 + 1, idx].add_patch(rect)
        axes[len(parameters) + idx2 + 1, idx].set_xlabel(parameters[idx2], fontsize=12, fontweight='bold')
        axes[len(parameters) + idx2 + 1, idx].set_ylabel(parameters[(idx2+1) % 3], fontsize=12, fontweight='bold')
        axes[len(parameters) + idx2 + 1, idx].set_title(f'Joint Posterior p({ps[idx2]}, {ps[(idx2+1) % 3]} | data)\nTrue: {ps[idx2]}={true_list[idx2]}, {ps[(idx2+1) % 3]}={true_list[(idx2+1) % 3]}', fontsize=12, fontweight='bold')
        axes[len(parameters) + idx2 + 1, idx].legend(loc='upper right', fontsize=8)
        axes[len(parameters) + idx2 + 1, idx].grid(True, alpha=0.3)

    
plt.tight_layout()
plt.show()
# Out:
# Loaded DINGOModel from Dingo.pt
#   Best epoch: 196
#   Best validation log prob: 7.3771
# Testing NPE model on new observations:
#
#
# Test 1: True Frequency = 1.0, True Phase = 0.50, True Amplitude = 1.00
#   Frequency posterior: mean=0.997 ± 0.014
#   Phase posterior:     mean=0.542 ± 0.040
#   Amplitude posterior: mean=1.014 ± 0.014
# /tmp/ipykernel_17825/2181378104.py:102: UserWarning: You passed a edgecolor/edgecolors ('white') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   axes[len(parameters) + idx2 + 1, idx].scatter(true_list[idx2], true_list[(idx2+1) % 3], color='cyan', s=200, marker='x',
# Test 2: True Frequency = 2.5, True Phase = -0.30, True Amplitude = 0.80
#   Frequency posterior: mean=2.558 ± 0.031
#   Phase posterior:     mean=-0.294 ± 0.042
#   Amplitude posterior: mean=0.796 ± 0.011
#
# Test 3: True Frequency = 4.0, True Phase = 1.20, True Amplitude = 2.40
#   Frequency posterior: mean=3.993 ± 0.016
#   Phase posterior:     mean=1.232 ± 0.017
#   Amplitude posterior: mean=2.414 ± 0.010

# %% [markdown]
# # TODO FOR JHPY
# DONT MARK ANYTHING DONE UNTIL YOU ARE SURE IT WORKS YA DUMMY
#
#
# - Combine Sin functions --> Done
# - Layers --> Done
# - Models --> Done
# - get all Neural Network Functions working
#     - Training function
#         - Data --> Done
#         - Loss --> Done
#         - Dropout + add to predictor --> Done
#         - Gradient Clipping --> Done
#     - Models should take config to allow param search
#     - convert DINGOmodel to just be a specific config
# - Create custom model to test things
# - Get claude to check all docstrings

# %% [markdown]
# # Dev ground
